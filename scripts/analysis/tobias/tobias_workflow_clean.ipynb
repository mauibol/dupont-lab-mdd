# %%
# Maddy Peng -- 2/10/25

# %% [markdown]
# ## Tobias workflow
#
# Starting from filtering the BAM files with given barcodes for each sample and cell type.
# **See R script for generating these barcodes and peak files**

# %%
# Install pysam if you don't have it already
# !pip install pysam
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pysam in /users/mp4486/.local/lib/python3.12/site-packages (0.23.0)

# %%
import subprocess
import pysam
import pandas as pd
import numpy as np
import os
import re

# %%
# Get working directory
# !pwd
# Out:
# /groups/mb928_gp/mp4486/tobias

# %%
# Read in metadata to get diagnoses
meta = pd.read_csv("../Multiome_process/meta/current_working_multiome_meta (1).csv")
# Out:
# /tmp/mp4486/ipykernel_409004/2772505042.py:2: DtypeWarning: Columns (28,31,32,38,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv("../Multiome_process/meta/current_working_multiome_meta (1).csv")

# %%
meta['sample']
# Out:
# 0         CM021
# 1         CM021
# 2         CM021
# 3         CM021
# 4         CM021
#           ...
# 495032    MM152
# 495033    MM152
# 495034    MM152
# 495035    MM152
# 495036    MM152
# Name: sample, Length: 495037, dtype: object

# %%
# Get IDs from the metadata
ids = list(set(meta['sample']))
len(ids)
# Out:
# 74

# %%
# Filter meta to just get the sample and donor/diagnosis
meta = meta[meta['sample'].isin(ids)]
dx = meta[['sample','Diagnosis']].drop_duplicates()

# %%
dx
# Out:
#        sample Diagnosis
# 0       CM021      NONE
# 2222    CM023      NONE
# 7526    CM024      NONE
# 14429   CM025       MDD
# 20707   CM026      NONE
# ...       ...       ...
# 486334  MM148      NONE
# 489199  MM149      NONE
# 490177  MM150      NONE
# 491058  MM151      NONE
# 493275  MM152      NONE
#
# [74 rows x 2 columns]

# %%
# Create a dictionary for control and mdd samples
dx_dict = {'control':[], 'mdd':[]}
for i in range(len(dx)):
    if dx.iloc[i]['Diagnosis'][0] == 'N':
        dx_dict['control'].append(dx.iloc[i]['sample'])
    else:
        dx_dict['mdd'].append(dx.iloc[i]['sample'])

# %%
cell_types = ['GC.1', 'ExN.1', 'InN.5']

# %%
# Get all the bam file paths per sample
def get_bam_path(i):
    if i[:2] == 'CM':
        path = "/groups/mb928_gp/data_backup/ngs/release/singleCell/220502_MAURA_CHEICK_16_HUMAN_SEQUENCING/bamfiles/"

    else:
        if re.match(r"^(00[1-9]|0[12][0-9]|03[01])$", i[2:5]):
            path = "/groups/mb928_gp/data_backup/230817_MAURA_MADELINE_12_HUMAN_10X/bamfiles/"

        elif re.match(r"^(14[5-9]|15[0-2])$", i[2:5]):
            path = "/groups/mb928_gp/data_backup/250131_MAURA_MADELINE_7_HUMAN_LIBRARY_SELF_3B_PE150_X/BAM_Multiome/"
        else:    
            path = "/groups/mb928_gp/data_backup/240806_MAURA_MADELINE_6_HUMAN_LIBRARY_10X/BAM/"

    return path + f"{i}_atac_possorted_bam.bam"

    
bam_paths = [get_bam_path(i) for i in ids]

# %%
len(bam_paths)
# Out:
# 74

# %%
# Define filtering function: Use pysam for filtering bam by barcode
def filter_bam_by_barcode(input_bam, barcode_file, output_bam):
    """Filter a BAM file to keep only reads with barcodes from a given list."""
    if os.path.exists(output_bam):
        print(f"{output_bam} already exits!")
        return

    if not os.path.exists(barcode_file):
        print(f"{barcode_file} does not exist ..... skipping .......")
        return

    print(input_bam)
        
    # Read barcode list from file
    with open(barcode_file, 'r') as f:
        barcodes = set(line.strip() for line in f)
    
    # Open input BAM and create an output BAM
    with pysam.AlignmentFile(input_bam, "r") as bam_in, \
         pysam.AlignmentFile(output_bam, "wb", template=bam_in) as bam_out:
        
        for read in bam_in:
            # Extract barcode from read (Assumes barcode is stored in a tag, e.g., 'CB' for 10x data)
            barcode = read.get_tag('CB') if read.has_tag('CB') else None
            
            if barcode and f"CB:Z:{barcode}" in barcodes:
                bam_out.write(read)

    print(f"Filtered BAM saved: {output_bam}")


def process_sample(args):
    c, sample_id, input_bam = args
    output_path = f"CURRENT/filtered_bams/{c}"
    os.makedirs(output_path, exist_ok=True)

    barcode_file = f"CURRENT/barcodes/{sample_id}_{c}.txt"
    output_bam = f"{output_path}/{sample_id}_filtered.bam"
    
    filter_bam_by_barcode(input_bam, barcode_file, output_bam)

# %%
# Check number of cores available
# !nproc
# Out:
# 128

# %%
# Nested for loop: for each cell type loop through each sample 
from concurrent.futures import ProcessPoolExecutor

# Prepare all tasks
tasks = []
for c in cell_types:
    for i in range(len(ids)):
        tasks.append((c, ids[i], bam_paths[i]))

# Run in parallel
with ProcessPoolExecutor(max_workers=128) as executor:
    executor.map(process_sample, tasks)

# %%
# Define merge bam file function: use pysam to merge
def merge_bam_files(args):
    """Merge BAM files for a given cell type and condition."""
    condition, cell_type, bam_list, output_dir = args
    
    if not bam_list:
        return f"No BAMs to merge for {cell_type} - {condition}"

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    output_path = os.path.join(output_dir, f"{condition}_merged.bam")

    if os.path.exists(output_path):
        print(f"{condition} {cell_type} already exists")
        return
    
    pysam.merge("-f", output_path, *bam_list)
    print(f"Merged {condition} BAM for {cell_type}: {output_path}")

# Prepare tasks
merge_tasks = []
for c in cell_types:
    bam_path = f"CURRENT/filtered_bams/{c}"

    ctrl_bams = [f"{bam_path}/{i}_filtered.bam" for i in dx_dict['control'] if os.path.exists(f"{bam_path}/{i}_filtered.bam")]
    mdd_bams = [f"{bam_path}/{i}_filtered.bam" for i in dx_dict['mdd'] if os.path.exists(f"{bam_path}/{i}_filtered.bam")]

    merge_tasks.append(("control", c, ctrl_bams, f"CURRENT/merged_bams/{c}"))
    merge_tasks.append(("mdd", c, mdd_bams, f"CURRENT/merged_bams/{c}"))

# %%
# Run in parallel
with ProcessPoolExecutor(max_workers=8) as executor:
    executor.map(merge_bam_files, merge_tasks)
# Out:
# control ImGC.2 already existscontrol NB already exists

# %%
# !pip install tobias

# %%
cell_types
# Out:
# ['NSC', 'INP']

# %%
# !pwd
# Out:
# /groups/mb928_gp/mp4486/tobias

# %%
# Run TOBIAS ATACorrect

import os
import subprocess
from concurrent.futures import ProcessPoolExecutor

# Constants
genome_fasta = "/groups/mb928_gp/adr2189/TOBIAS/Tobias_footprinting_non_GN/ATACorrect_input/genome.fa"
blacklist = "/groups/mb928_gp/adr2189/TOBIAS/Tobias_footprinting_non_GN/ATACorrect_input/ENCFF356LFX_blacklist.bed"
peaks_dir = 'CURRENT/peak_files'
output_root = 'CURRENT/merged_bams'

# Build tasks: (group, cell_type, bam_file, peak_file, output_dir)
tasks = []
for group in ['control','mdd']:
    for c in cell_types:
        bam_file = f"{output_root}/{c}/{group}_merged.bam"
        peak_file = f"{peaks_dir}/{c}.bed"
        output_dir = f"{output_root}/{c}"
        output_prefix = f"{output_dir}/{group}_corrected"

        if os.path.exists(bam_file) and os.path.exists(peak_file):
            tasks.append((bam_file, peak_file, output_prefix, output_dir))

print(tasks)
# Function to run TOBIAS ATACorrect
def run_tobias(task):
    bam_file, peaks_file, output_prefix, outdir = task
    cell_type = os.path.basename(peaks_file).split('.')[0]
    print(f"Running TOBIAS ATACorrect for {cell_type}")

    command = [
        "TOBIAS", "ATACorrect",
        "--bam", bam_file,
        "--genome", genome_fasta,
        "--blacklist", blacklist,
        "--peaks", peaks_file,
        "--outdir", outdir,
        "--prefix", os.path.basename(output_prefix),
        "--cores", "4"
    ]
    
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(result.stdout.decode())
    if result.stderr:
        print(result.stderr.decode())

# Run in parallel
with ProcessPoolExecutor(max_workers=4) as executor:
    executor.map(run_tobias, tasks)

# %%
# Run TOBIAS footprint scores

from concurrent.futures import ProcessPoolExecutor

peaks_dir = 'CURRENT/peak_files'
genome_dir = 'CURRENT/merged_bams'
conditions = ['control', 'mdd']

def prepare_args(condition, cell_type):
    corrected_file = f"{genome_dir}/{cell_type}/{condition}_corrected_corrected.bw"
    peaks_file = f"{peaks_dir}/{cell_type}.bed"
    output_dir = f"{genome_dir}/{cell_type}/footprints"
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f"{condition}_footprints.bw")
    return (condition, cell_type, corrected_file, peaks_file, output_file)

def process_task(args):
    condition, cell_type, corrected_file, peaks_file, output_file = args
    print(f"Running TOBIAS FootprintScores for {cell_type} ({condition})")
    
    command = [
        "TOBIAS", "FootprintScores",
        "--signal", corrected_file,
        "--regions", peaks_file,
        "--output", output_file,
        "--cores", "4"
    ]

    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    print(f"[{condition} - {cell_type}] STDOUT:\n{result.stdout.decode()}")
    print(f"[{condition} - {cell_type}] STDERR:\n{result.stderr.decode()}")

# Create task list
args_list = [prepare_args(cond, ct) for cond in conditions for ct in cell_types]

# Run in parallel
with ProcessPoolExecutor(max_workers=4) as executor:
    executor.map(process_task, args_list)

# %%
# UROPA
import os
import subprocess
from concurrent.futures import ProcessPoolExecutor

# Directory containing peak files
peaks_dir = 'CURRENT/peak_files'
output_dir = 'CURRENT/uropa_output'
os.makedirs(output_dir, exist_ok=True)

# GTF file path
gtf_file = "/groups/mb928_gp/adr2189/TOBIAS/Tobias_footprinting_non_GN/ATACorrect_input/Homo_sapiens.GRCh38.113.chr.gtf"

# Function to run uropa for a single peak file
def run_uropa(peak_file):
    print(f"Running uropa for: {peak_file}")
    command = [
        "uropa",
        "--bed", peak_file,
        "--gtf", gtf_file,
        "--show_attributes", "gene_id", "gene_name",
        "--feature_anchor", "start",
        "--distance", "20000", "10000",
        "--feature", "gene",
        "--outdir", output_dir
    ]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(result.stdout.decode())
    print(result.stderr.decode())

# Get all .bed files in the peak directory
peak_files = [os.path.join(peaks_dir, f"{c}.bed") for c in cell_types]

# Run in parallel
with ProcessPoolExecutor(max_workers=4) as executor:
    executor.map(run_uropa, peak_files)

# %%
#Cut files
uropa_output_dir = 'CURRENT/uropa_output'

# Function to run cut header
def run_cut_header(cell_type):
    final_hits = os.path.join(uropa_output_dir, f"{cell_type}_finalhits.txt")
    header_output = os.path.join(uropa_output_dir, f"{cell_type}_annotated_header.txt")
    
    command = f"cut -f 1-6,16-17 {final_hits} | head -n 1 > {header_output}"
    subprocess.run(command, shell=True, check=True)
    print(f"Header saved for {cell_type}")

# Function to run cut body (without header)
def run_cut(cell_type):
    final_hits = os.path.join(uropa_output_dir, f"{cell_type}_finalhits.txt")
    body_output = os.path.join(uropa_output_dir, f"{cell_type}_annotated.bed")
    
    command = f"cut -f 1-6,16-17 {final_hits} | tail -n +2 > {body_output}"
    subprocess.run(command, shell=True, check=True)
    print(f"Annotated BED saved for {cell_type}")

# Parallel execution
with ProcessPoolExecutor(max_workers=4) as executor:
    executor.map(run_cut_header, cell_types)
    executor.map(run_cut, cell_types)

# %%
# Run bin detect

genome_fasta = "/groups/mb928_gp/adr2189/TOBIAS/Tobias_footprinting_non_GN/ATACorrect_input/genome.fa"
motif_file = "/groups/mb928_gp/adr2189/TOBIAS/Tobias_footprinting_non_GN/JASPAR2024.jaspar"
uropa_output_dir = 'CURRENT/uropa_output'

def run_bin_detect(cell_type):
    base = 'CURRENT/merged_bams'
    ctrl_fp = f"{base}/{cell_type}/footprints/control_footprints.bw"
    mdd_fp = f"{base}/{cell_type}/footprints/mdd_footprints.bw"
    
    peaks = f"{uropa_output_dir}/{cell_type}_annotated.bed"
    header = f"{uropa_output_dir}/{cell_type}_annotated_header.txt"
    output_dir = f"CURRENT/BINDetect_output/{cell_type}"
    os.makedirs(output_dir, exist_ok=True)

    cmd = [
        "TOBIAS", "BINDetect",
        "--motifs", motif_file,
        "--signals", mdd_fp, ctrl_fp,
        "--genome", genome_fasta,
        "--peaks", peaks,
        "--peak_header", header,
        "--outdir", output_dir,
        "--cond_names", f"{cell_type}MDD", f"{cell_type}CTRL",
        "--cores", "4"
    ]

    try:
        subprocess.run(cmd, check=True)
        print(f"BINDetect ran for {cell_type}")
    except subprocess.CalledProcessError as e:
        print(f"Error running BINDetect for {cell_type}: {e}")

# Run in parallel
with ProcessPoolExecutor(max_workers=4) as executor:
    executor.map(run_bin_detect, cell_types)

# %%
# !pwd
# Out:
# /groups/mb928_gp/mp4486/tobias

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "4"

# %%
import subprocess
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import os

# List of cell types
cell_types = ["GN.1", "GN.2", "ExN.1", "InN.5"]

# Significance thresholds
PVAL_THRESHOLD = 0.05
CHANGE_THRESHOLD = 0.1

# Function to extract significant TFs for a given cell type
def get_significant_tfs(cell):
    bindetect_path = f"CURRENT/BINDetect_output/{cell}/bindetect_results.txt"
    if not os.path.exists(bindetect_path):
        print(f"⚠️  Missing BINDetect file for {cell}")
        return []

    df = pd.read_csv(bindetect_path, sep="\t")

    # Dynamically build column names
    change_col = f"{cell}MDD_{cell}CTRL_change"
    pval_col = f"{cell}MDD_{cell}CTRL_pvalue"

    if change_col not in df.columns or pval_col not in df.columns:
        print(f"⚠️  Columns missing in {bindetect_path}: {change_col}, {pval_col}")
        return []

    sig_df = df[(df[pval_col] < PVAL_THRESHOLD) & (df[change_col].abs() > CHANGE_THRESHOLD)]

    # Format: Name_MotifID
    significant_tfs = (sig_df["name"] + "_" + sig_df["motif_id"]).tolist()
    return significant_tfs

# Function to run TOBIAS PlotAggregate for a (cell, tf) combo
def run_plotaggregate(cell_tf):
    cell, tf = cell_tf
    tfbs_bed = f"CURRENT/BINDetect_output/{cell}/{tf}/beds/{tf}_all.bed"
    output_file = f"CURRENT/plots/{cell}_{tf}_plotaggregate.pdf"
    title = f"{cell} {tf} Aggregated Signals"

    if not os.path.exists(tfbs_bed):
        print(f"⚠️  Missing TFBS bed file: {tfbs_bed}")
        return

    cmd = [
        "TOBIAS", "PlotAggregate",
        "--signals",
        f"CURRENT/merged_bams/{cell}/footprints/control_footprints.bw",
        f"CURRENT/merged_bams/{cell}/footprints/mdd_footprints.bw",
        "--TFBS", tfbs_bed,
        "--output", output_file,
        "--signal_labels", "control", "mdd",
        "--title", title
    ]

    try:
        subprocess.run(cmd, check=True)
        print(f"✅ Finished: {cell} x {tf}")
    except subprocess.CalledProcessError as e:
        print(f"❌ Error running for {cell} x {tf}: {e}")

# Build task list
tasks = []
for cell in cell_types:
    tfs = get_significant_tfs(cell)
    print(f"📌 {cell}: {len(tfs)} significant TFs")
    tasks.extend([(cell, tf) for tf in tfs])

with ThreadPoolExecutor(max_workers=16) as executor:
        executor.map(run_plotaggregate, tasks)
# Out:
# 📌 GN.1: 240 significant TFs
# 📌 GN.2: 11 significant TFs
# 📌 ExN.1: 82 significant TFs
# 📌 InN.5: 163 significant TFs
# ⚠️  Missing TFBS bed file: CURRENT/BINDetect_output/GN.1/NFIC::TLX1_MA0119.1/beds/NFIC::TLX1_MA0119.1_all.bed
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 14:13:27.845175)
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 14:13:27.845191)
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 14:13:27.845198)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/TFAP4_MA0691.1/beds/TFAP4_MA0691.1_all.bed --output CURRENT/plots/GN.1_TFAP4_MA0691.1_plotaggregate.pdf --signal_labels control mdd --title GN.1 TFAP4_MA0691.1 Aggregated Signals
#
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/PROP1_MA0715.1/beds/PROP1_MA0715.1_all.bed --output CURRENT/plots/GN.1_PROP1_MA0715.1_plotaggregate.pdf --signal_labels control mdd --title GN.1 PROP1_MA0715.1 Aggregated Signals
#
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/HNF1B_MA0153.2/beds/HNF1B_MA0153.2_all.bed --output CURRENT/plots/GN.1_HNF1B_MA0153.2_plotaggregate.pdf --signal_labels control mdd --title GN.1 HNF1B_MA0153.2 Aggregated Signals
#
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 14:13:27.845289)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 14:13:27.845347)
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/MEF2B_MA0660.1/beds/MEF2B_MA0660.1_all.bed --output CURRENT/plots/GN.1_MEF2B_MA0660.1_plotaggregate.pdf --signal_labels control mdd --title GN.1 MEF2B_MA0660.1 Aggregated Signals
#
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/Arid3a_MA0151.1/beds/Arid3a_MA0151.1_all.bed --output CURRENT/plots/GN.1_Arid3a_MA0151.1_plotaggregate.pdf --signal_labels control mdd --title GN.1 Arid3a_MA0151.1 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/TFAP4_MA0691.1/beds/TFAP4_MA0691.1_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_TFAP4_MA0691.1_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 TFAP4_MA0691.1 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/PROP1_MA0715.1/beds/PROP1_MA0715.1_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_PROP1_MA0715.1_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 PROP1_MA0715.1 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # CURRENT/plots/GN.1_TFAP4_MA0691.1_plotaggregate.pdf
# # ----- Output files -----
#
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/HNF1B_MA0153.2/beds/HNF1B_MA0153.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (control,Irf1_MA0050.4_all): 40 0.28801 0.27802 -0.00999
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (control,Irf1_MA0050.4_all): 42 0.28821 0.27812 -0.01010
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (control,Irf1_MA0050.4_all): 44 0.28841 0.27823 -0.01018
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (control,Irf1_MA0050.4_all): 46 0.28861 0.27837 -0.01024
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (control,Irf1_MA0050.4_all): 48 0.28879 0.27851 -0.01028
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 10 0.34909 0.34085 -0.00824
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 12 0.34925 0.34084 -0.00841
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 14 0.34941 0.34084 -0.00857
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 16 0.34957 0.34083 -0.00874
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 18 0.34974 0.34084 -0.00890
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 20 0.34992 0.34082 -0.00911
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 22 0.35011 0.34080 -0.00931
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 24 0.35031 0.34077 -0.00954
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 26 0.35052 0.34076 -0.00976
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 28 0.35073 0.34076 -0.00997
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 30 0.35095 0.34076 -0.01019
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 32 0.35118 0.34078 -0.01040
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 34 0.35141 0.34081 -0.01060
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 36 0.35164 0.34086 -0.01078
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 38 0.35187 0.34093 -0.01094
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 40 0.35210 0.34101 -0.01109
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 42 0.35233 0.34112 -0.01121
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 44 0.35255 0.34125 -0.01130
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 46 0.35277 0.34139 -0.01137
# 2025-04-23 14:19:38 (2302094) [STATS]	FPD (mdd,Irf1_MA0050.4_all): 48 0.35297 0.34155 -0.01142
#
# 2025-04-23 14:19:38 (2302094) [INFO]	Calculating measures for comparing pairwise aggregates
# 2025-04-23 14:19:38 (2302094) [INFO]	CORRELATION (signal1,region1) VS (signal2,region2): PEARSONR	SUM_DIFF
# 2025-04-23 14:19:38 (2302094) [STATS]	CORRELATION (control,Irf1_MA0050.4_all) VS (mdd,Irf1_MA0050.4_all): 0.99905	7.64709
#
# 2025-04-23 14:19:38 (2302094) [INFO]	---- Plotting aggregates ----
# 2025-04-23 14:19:38 (2302094) [INFO]	Setting up plotting grid
# 2025-04-23 14:19:38 (2302094) [INFO]	Plotting regions Irf1_MA0050.4_all from signal control
# 2025-04-23 14:19:38 (2302094) [INFO]	Plotting regions Irf1_MA0050.4_all from signal mdd
# 2025-04-23 14:19:38 (2302094) [INFO]	Adjusting final details
#
# 2025-04-23 14:19:38 (2302094) [INFO]	Finished PlotAggregate run (total time elapsed: 0:00:09.629520)
# ✅ Finished: InN.5 x Irf1_MA0050.4

# %%
tasks
# Out:
# [('GN.1', 'Arnt_MA0004.1'),
#  ('GN.1', 'NFIC::TLX1_MA0119.1'),
#  ('GN.1', 'Arid3a_MA0151.1'),
#  ('GN.1', 'PLAG1_MA0163.1'),
#  ('GN.1', 'Tfcp2l1_MA0145.2'),
#  ('GN.1', 'KLF5_MA0599.1'),
#  ('GN.1', 'Creb3l2_MA0608.1'),
#  ('GN.1', 'HNF1B_MA0153.2'),
#  ('GN.1', 'JDP2_MA0655.1'),
#  ('GN.1', 'MEF2B_MA0660.1'),
#  ('GN.1', 'MLX_MA0663.1'),
#  ('GN.1', 'TFAP4_MA0691.1'),
#  ('GN.1', 'ZIC1_MA0696.1'),
#  ('GN.1', 'PHOX2A_MA0713.1'),
#  ('GN.1', 'PROP1_MA0715.1'),
#  ('GN.1', 'EGR2_MA0472.2'),
#  ('GN.1', 'GLIS2_MA0736.1'),
#  ('GN.1', 'KLF16_MA0741.1'),
#  ('GN.1', 'MEF2D_MA0773.1'),
#  ('GN.1', 'PAX3_MA0780.1'),
#  ('GN.1', 'POU3F2_MA0787.1'),
#  ('GN.1', 'POU3F3_MA0788.1'),
#  ('GN.1', 'TFAP2B_MA0813.1'),
#  ('GN.1', 'TFAP2C_MA0815.1'),
#  ('GN.1', 'Ascl2_MA0816.1'),
#  ('GN.1', 'HEY1_MA0823.1'),
#  ('GN.1', 'FOXB1_MA0845.1'),
#  ('GN.1', 'FOXC1_MA0032.2'),
#  ('GN.1', 'TFAP2A_MA0872.1'),
#  ('GN.1', 'FERD3L_MA1485.1'),
#  ('GN.1', 'ZBTB32_MA1580.1'),
#  ('GN.1', 'ZNF8_MA1718.1'),
#  ('GN.1', 'Foxn1_MA1684.1'),
#  ('GN.1', 'POU2F1::SOX2_MA1962.1'),
#  ('GN.1', 'ZNF669_MA1985.1'),
#  ('GN.1', 'SP1_MA0079.5'),
#  ('GN.1', 'SP2_MA0516.3'),
#  ('GN.1', 'SP4_MA0685.2'),
#  ('GN.1', 'KLF14_MA0740.2'),
#  ('GN.1', 'KLF12_MA0742.2'),
#  ('GN.1', 'HES5_MA0821.2'),
#  ('GN.1', 'TFE3_MA0831.3'),
#  ('GN.1', 'KLF10_MA1511.2'),
#  ('GN.1', 'BACH1_MA1633.2'),
#  ('GN.1', 'mix-a_MA0621.2'),
#  ('GN.1', 'EPAS1_MA2325.1'),
#  ('GN.1', 'ZBED4_MA2328.1'),
#  ('GN.1', 'ZBTB11_MA2329.1'),
#  ('GN.1', 'ZBTB24_MA2330.1'),
#  ('GN.1', 'ZNF35_MA2333.1'),
#  ('GN.1', 'ZNF558_MA2335.1'),
#  ('GN.1', 'ALX3_MA0634.2'),
#  ('GN.1', 'ARGFX_MA1463.2'),
#  ('GN.1', 'ARNT2_MA1464.2'),
#  ('GN.1', 'ASCL1_MA1100.3'),
#  ('GN.1', 'BARX2_MA1471.2'),
#  ('GN.1', 'BHLHE22_MA1635.2'),
#  ('GN.1', 'CDX4_MA1473.2'),
#  ('GN.1', 'CTCF_MA0139.2'),
#  ('GN.1', 'CTCF_MA1929.2'),
#  ('GN.1', 'CTCF_MA1930.2'),
#  ('GN.1', 'CTCFL_MA1102.3'),
#  ('GN.1', 'CUX1_MA0754.3'),
#  ('GN.1', 'HOXB13_MA0901.3'),
#  ('GN.1', 'CUX2_MA0755.2'),
#  ('GN.1', 'DBP_MA0639.2'),
#  ('GN.1', 'DRGX_MA1481.2'),
#  ('GN.1', 'E2F6_MA0471.3'),
#  ('GN.1', 'E2F8_MA0865.3'),
#  ('GN.1', 'EGR1_MA0162.5'),
#  ('GN.1', 'EGR3_MA0732.2'),
#  ('GN.1', 'EGR4_MA0733.2'),
#  ('GN.1', 'ELK1_MA0028.3'),
#  ('GN.1', 'HOXA1_MA1495.2'),
#  ('GN.1', 'PAX5_MA0014.4'),
#  ('GN.1', 'ELK1::SREBF2_MA1933.2'),
#  ('GN.1', 'TEF_MA0843.2'),
#  ('GN.1', 'ELK3_MA0759.3'),
#  ('GN.1', 'ELK4_MA0076.3'),
#  ('GN.1', 'EMX1_MA0612.3'),
#  ('GN.1', 'EMX2_MA0886.2'),
#  ('GN.1', 'EN1_MA0027.3'),
#  ('GN.1', 'MAX_MA0058.4'),
#  ('GN.1', 'ERF::NHLH1_MA1938.2'),
#  ('GN.1', 'NHLH1_MA0048.3'),
#  ('GN.1', 'ETS2_MA1484.2'),
#  ('GN.1', 'ETV4_MA0764.4'),
#  ('GN.1', 'ETV5_MA0765.4'),
#  ('GN.1', 'HOXA2_MA0900.3'),
#  ('GN.1', 'EVX1_MA0887.2'),
#  ('GN.1', 'EVX2_MA0888.2'),
#  ('GN.1', 'FEV_MA0156.4'),
#  ('GN.1', 'FOS_MA0476.2'),
#  ('GN.1', 'FOS::JUN_MA0099.4'),
#  ('GN.1', 'FOS::JUNB_MA1134.2'),
#  ('GN.1', 'JUNB_MA0490.3'),
#  ('GN.1', 'FOS::JUND_MA1141.2'),
#  ('GN.1', 'JUND_MA0491.3'),
#  ('GN.1', 'FOSB::JUNB_MA1135.2'),
#  ('GN.1', 'FOSL1_MA0477.3'),
#  ('GN.1', 'FOSL1::JUN_MA1128.2'),
#  ('GN.1', 'FOSL1::JUNB_MA1137.2'),
#  ('GN.1', 'FOSL1::JUND_MA1142.2'),
#  ('GN.1', 'FOSL2::JUN_MA1130.2'),
#  ('GN.1', 'FOSL2::JUNB_MA1138.2'),
#  ('GN.1', 'FOSL2::JUND_MA1144.2'),
#  ('GN.1', 'FOXC2_MA0846.2'),
#  ('GN.1', 'FOXD2_MA0847.4'),
#  ('GN.1', 'FOXD3_MA0041.3'),
#  ('GN.1', 'GSX1_MA0892.2'),
#  ('GN.1', 'HES1_MA1099.3'),
#  ('GN.1', 'HES2_MA0616.3'),
#  ('GN.1', 'HEY2_MA0649.2'),
#  ('GN.1', 'HINFP_MA0131.3'),
#  ('GN.1', 'HLF_MA0043.4'),
#  ('GN.1', 'HNF1A_MA0046.3'),
#  ('GN.1', 'HOXA10_MA0899.2'),
#  ('GN.1', 'HOXB2_MA0902.3'),
#  ('GN.1', 'HOXB3_MA0903.2'),
#  ('GN.1', 'HOXB5_MA0904.3'),
#  ('GN.1', 'HOXC10_MA0905.2'),
#  ('GN.1', 'HOXC12_MA0906.2'),
#  ('GN.1', 'HOXC8_MA1505.2'),
#  ('GN.1', 'HOXD11_MA0908.2'),
#  ('GN.1', 'HOXD9_MA0913.3'),
#  ('GN.1', 'ISX_MA0654.2'),
#  ('GN.1', 'KLF1_MA0493.3'),
#  ('GN.1', 'KLF11_MA1512.2'),
#  ('GN.1', 'KLF15_MA1513.2'),
#  ('GN.1', 'KLF2_MA1515.2'),
#  ('GN.1', 'KLF3_MA1516.2'),
#  ('GN.1', 'KLF4_MA0039.5'),
#  ('GN.1', 'KLF6_MA1517.2'),
#  ('GN.1', 'KLF7_MA1959.2'),
#  ('GN.1', 'LMX1A_MA0702.3'),
#  ('GN.1', 'LMX1B_MA0703.3'),
#  ('GN.1', 'MYC_MA0147.4'),
#  ('GN.1', 'MAZ_MA1522.2'),
#  ('GN.1', 'MEF2A_MA0052.5'),
#  ('GN.1', 'MEF2C_MA0497.2'),
#  ('GN.1', 'MIXL1_MA0662.2'),
#  ('GN.1', 'MLXIPL_MA0664.2'),
#  ('GN.1', 'MNT_MA0825.2'),
#  ('GN.1', 'MNX1_MA0707.3'),
#  ('GN.1', 'MYCN_MA0104.5'),
#  ('GN.1', 'MYF5_MA1641.2'),
#  ('GN.1', 'MYOG_MA0500.3'),
#  ('GN.1', 'NEUROD1_MA1109.2'),
#  ('GN.1', 'NEUROG2_MA1642.2'),
#  ('GN.1', 'NFIB_MA1643.2'),
#  ('GN.1', 'NFIC_MA1527.2'),
#  ('GN.1', 'NFIL3_MA0025.3'),
#  ('GN.1', 'NFIX_MA1528.2'),
#  ('GN.1', 'NHLH2_MA1529.2'),
#  ('GN.1', 'NKX6-1_MA0674.2'),
#  ('GN.1', 'NKX6-2_MA0675.2'),
#  ('GN.1', 'ONECUT1_MA0679.3'),
#  ('GN.1', 'ONECUT3_MA0757.2'),
#  ('GN.1', 'PATZ1_MA1961.2'),
#  ('GN.1', 'PBX2_MA1113.3'),
#  ('GN.1', 'PDX1_MA0132.3'),
#  ('GN.1', 'PHOX2B_MA0681.3'),
#  ('GN.1', 'PLAGL2_MA1548.2'),
#  ('GN.1', 'POU3F1_MA0786.2'),
#  ('GN.1', 'POU4F1_MA0790.2'),
#  ('GN.1', 'POU4F2_MA0683.2'),
#  ('GN.1', 'POU4F3_MA0791.2'),
#  ('GN.1', 'POU6F1_MA0628.2'),
#  ('GN.1', 'PRRX1_MA0716.2'),
#  ('GN.1', 'SATB1_MA1963.2'),
#  ('GN.1', 'SP3_MA0746.3'),
#  ('GN.1', 'SP8_MA0747.2'),
#  ('GN.1', 'SP9_MA1564.2'),
#  ('GN.1', 'TCFL5_MA0632.3'),
#  ('GN.1', 'TFAP2A_MA0810.2'),
#  ('GN.1', 'TFAP2A_MA0003.5'),
#  ('GN.1', 'TFAP2B_MA0811.2'),
#  ('GN.1', 'TFAP2B_MA0812.2'),
#  ('GN.1', 'TFAP2C_MA0524.3'),
#  ('GN.1', 'TFAP2E_MA1569.2'),
#  ('GN.1', 'TFAP4::ETV1_MA1966.2'),
#  ('GN.1', 'TFAP4::FLI1_MA1967.2'),
#  ('GN.1', 'TFDP1_MA1122.2'),
#  ('GN.1', 'TFEC_MA0871.3'),
#  ('GN.1', 'TLX2_MA1577.2'),
#  ('GN.1', 'TWIST1_MA1123.3'),
#  ('GN.1', 'UNCX_MA0721.2'),
#  ('GN.1', 'USF2_MA0526.5'),
#  ('GN.1', 'VAX2_MA0723.3'),
#  ('GN.1', 'YY2_MA0748.3'),
#  ('GN.1', 'ZBTB14_MA1650.2'),
#  ('GN.1', 'ZBTB33_MA0527.2'),
#  ('GN.1', 'ZFP57_MA1583.2'),
#  ('GN.1', 'ZIC4_MA0751.2'),
#  ('GN.1', 'ZIC5_MA1584.2'),
#  ('GN.1', 'ZNF148_MA1653.2'),
#  ('GN.1', 'ZNF211_MA1974.2'),
#  ('GN.1', 'ZNF281_MA1630.3'),
#  ('GN.1', 'ZNF320_MA1976.2'),
#  ('GN.1', 'ZNF343_MA1711.2'),
#  ('GN.1', 'ZNF354A_MA1978.2'),
#  ('GN.1', 'ZNF384_MA1125.2'),
#  ('GN.1', 'ZNF417_MA1727.2'),
#  ('GN.1', 'ZNF454_MA1712.2'),
#  ('GN.1', 'ZNF530_MA1981.2'),
#  ('GN.1', 'ZNF549_MA1728.2'),
#  ('GN.1', 'ZNF574_MA1982.2'),
#  ('GN.1', 'ZNF610_MA1713.2'),
#  ('GN.1', 'ZNF682_MA1599.2'),
#  ('GN.1', 'ZNF692_MA1986.2'),
#  ('GN.1', 'ZNF740_MA0753.3'),
#  ('GN.1', 'ZNF93_MA1721.2'),
#  ('GN.1', 'Hmga1_MA2124.1'),
#  ('GN.1', 'Zfp961_MA2126.1'),
#  ('GN.1', 'Zbtb2_MA2340.1'),
#  ('GN.1', 'Ahr::Arnt_MA0006.2'),
#  ('GN.1', 'Arid3b_MA0601.2'),
#  ('GN.1', 'Arid5a_MA0602.2'),
#  ('GN.1', 'Arntl_MA0603.2'),
#  ('GN.1', 'Atoh1_MA1467.3'),
#  ('GN.1', 'Bhlha15_MA1472.3'),
#  ('GN.1', 'Lhx3_MA0135.2'),
#  ('GN.1', 'Lhx4_MA0704.2'),
#  ('GN.1', 'Lhx8_MA0705.2'),
#  ('GN.1', 'Mlxip_MA0622.2'),
#  ('GN.1', 'Neurod2_MA1993.2'),
#  ('GN.1', 'Neurod2_MA0668.3'),
#  ('GN.1', 'Npas2_MA0626.2'),
#  ('GN.1', 'Nrf1_MA0506.3'),
#  ('GN.1', 'Olig2_MA1997.2'),
#  ('GN.1', 'Pax7_MA0680.3'),
#  ('GN.1', 'Plagl1_MA1615.2'),
#  ('GN.1', 'Ptf1A_MA1619.2'),
#  ('GN.1', 'Tcf12_MA0521.3'),
#  ('GN.1', 'Twist2_MA0633.3'),
#  ('GN.1', 'Wt1_MA1627.2'),
#  ('GN.1', 'Zfx_MA0146.3'),
#  ('GN.1', 'Zic1::Zic2_MA1628.2'),
#  ('GN.1', 'Zic3_MA0697.3'),
#  ('GN.1', 'TBP_MA0108.3'),
#  ('GN.2', 'ZBED4_MA2328.1'),
#  ('GN.2', 'CTCF_MA0139.2'),
#  ('GN.2', 'ELK1_MA0028.3'),
#  ('GN.2', 'ELK3_MA0759.3'),
#  ('GN.2', 'ETV4_MA0764.4'),
#  ('GN.2', 'ETV5_MA0765.4'),
#  ('GN.2', 'FEV_MA0156.4'),
#  ('GN.2', 'KLF15_MA1513.2'),
#  ('GN.2', 'TCFL5_MA0632.3'),
#  ('GN.2', 'ZNF610_MA1713.2'),
#  ('GN.2', 'Nrf1_MA0506.3'),
#  ('ExN.1', 'Tfcp2l1_MA0145.2'),
#  ('ExN.1', 'ZIC1_MA0696.1'),
#  ('ExN.1', 'EGR2_MA0472.2'),
#  ('ExN.1', 'GLIS2_MA0736.1'),
#  ('ExN.1', 'KLF16_MA0741.1'),
#  ('ExN.1', 'TFAP2B_MA0813.1'),
#  ('ExN.1', 'TFAP2C_MA0815.1'),
#  ('ExN.1', 'TFAP2A_MA0872.1'),
#  ('ExN.1', 'FERD3L_MA1485.1'),
#  ('ExN.1', 'Foxn1_MA1684.1'),
#  ('ExN.1', 'ZNF669_MA1985.1'),
#  ('ExN.1', 'SP1_MA0079.5'),
#  ('ExN.1', 'SP2_MA0516.3'),
#  ('ExN.1', 'SP4_MA0685.2'),
#  ('ExN.1', 'KLF14_MA0740.2'),
#  ('ExN.1', 'KLF12_MA0742.2'),
#  ('ExN.1', 'KLF10_MA1511.2'),
#  ('ExN.1', 'ZBED4_MA2328.1'),
#  ('ExN.1', 'ZBTB24_MA2330.1'),
#  ('ExN.1', 'ASCL1_MA1100.3'),
#  ('ExN.1', 'BHLHE22_MA1635.2'),
#  ('ExN.1', 'CREB3L4_MA1475.2'),
#  ('ExN.1', 'CTCF_MA1929.2'),
#  ('ExN.1', 'CTCF_MA1930.2'),
#  ('ExN.1', 'CTCFL_MA1102.3'),
#  ('ExN.1', 'E2F6_MA0471.3'),
#  ('ExN.1', 'E2F8_MA0865.3'),
#  ('ExN.1', 'EGR1_MA0162.5'),
#  ('ExN.1', 'EGR3_MA0732.2'),
#  ('ExN.1', 'EGR4_MA0733.2'),
#  ('ExN.1', 'PAX5_MA0014.4'),
#  ('ExN.1', 'NHLH1_MA0048.3'),
#  ('ExN.1', 'HES1_MA1099.3'),
#  ('ExN.1', 'HES2_MA0616.3'),
#  ('ExN.1', 'HINFP_MA0131.3'),
#  ('ExN.1', 'KLF1_MA0493.3'),
#  ('ExN.1', 'KLF11_MA1512.2'),
#  ('ExN.1', 'KLF15_MA1513.2'),
#  ('ExN.1', 'KLF2_MA1515.2'),
#  ('ExN.1', 'KLF3_MA1516.2'),
#  ('ExN.1', 'KLF7_MA1959.2'),
#  ('ExN.1', 'MAZ_MA1522.2'),
#  ('ExN.1', 'MYF5_MA1641.2'),
#  ('ExN.1', 'MYOG_MA0500.3'),
#  ('ExN.1', 'NFIX_MA1528.2'),
#  ('ExN.1', 'NHLH2_MA1529.2'),
#  ('ExN.1', 'PATZ1_MA1961.2'),
#  ('ExN.1', 'PLAGL2_MA1548.2'),
#  ('ExN.1', 'SP3_MA0746.3'),
#  ('ExN.1', 'SP9_MA1564.2'),
#  ('ExN.1', 'TCFL5_MA0632.3'),
#  ('ExN.1', 'TFAP2A_MA0810.2'),
#  ('ExN.1', 'TFAP2B_MA0811.2'),
#  ('ExN.1', 'TFAP2B_MA0812.2'),
#  ('ExN.1', 'TFAP2C_MA0524.3'),
#  ('ExN.1', 'TFAP2E_MA1569.2'),
#  ('ExN.1', 'TFDP1_MA1122.2'),
#  ('ExN.1', 'XBP1_MA0844.2'),
#  ('ExN.1', 'ZBTB14_MA1650.2'),
#  ('ExN.1', 'ZBTB33_MA0527.2'),
#  ('ExN.1', 'ZFP57_MA1583.2'),
#  ('ExN.1', 'ZIC4_MA0751.2'),
#  ('ExN.1', 'ZIC5_MA1584.2'),
#  ('ExN.1', 'ZNF148_MA1653.2'),
#  ('ExN.1', 'ZNF211_MA1974.2'),
#  ('ExN.1', 'ZNF281_MA1630.3'),
#  ('ExN.1', 'ZNF320_MA1976.2'),
#  ('ExN.1', 'ZNF454_MA1712.2'),
#  ('ExN.1', 'ZNF610_MA1713.2'),
#  ('ExN.1', 'ZNF682_MA1599.2'),
#  ('ExN.1', 'ZNF93_MA1721.2'),
#  ('ExN.1', 'Zfp961_MA2126.1'),
#  ('ExN.1', 'Bhlha15_MA1472.3'),
#  ('ExN.1', 'Neurod2_MA1993.2'),
#  ('ExN.1', 'Npas4_MA1995.2'),
#  ('ExN.1', 'Nrf1_MA0506.3'),
#  ('ExN.1', 'Olig2_MA1997.2'),
#  ('ExN.1', 'Ptf1A_MA1619.2'),
#  ('ExN.1', 'Tcf12_MA0521.3'),
#  ('ExN.1', 'Twist2_MA0633.3'),
#  ('ExN.1', 'Wt1_MA1627.2'),
#  ('ExN.1', 'Zfx_MA0146.3'),
#  ('InN.5', 'Pou5f1::Sox2_MA0142.1'),
#  ('InN.5', 'PLAG1_MA0163.1'),
#  ('InN.5', 'HNF1B_MA0153.2'),
#  ('InN.5', 'JDP2_MA0655.1'),
#  ('InN.5', 'MEF2B_MA0660.1'),
#  ('InN.5', 'OLIG2_MA0678.1'),
#  ('InN.5', 'SRF_MA0083.3'),
#  ('InN.5', 'ZIC1_MA0696.1'),
#  ('InN.5', 'PROP1_MA0715.1'),
#  ('InN.5', 'GLIS2_MA0736.1'),
#  ('InN.5', 'MEF2D_MA0773.1'),
#  ('InN.5', 'POU3F2_MA0787.1'),
#  ('InN.5', 'POU3F3_MA0788.1'),
#  ('InN.5', 'TFAP2B_MA0813.1'),
#  ('InN.5', 'TFAP2C_MA0815.1'),
#  ('InN.5', 'OLIG3_MA0827.1'),
#  ('InN.5', 'FOXB1_MA0845.1'),
#  ('InN.5', 'FOXC1_MA0032.2'),
#  ('InN.5', 'E2F1_MA0024.3'),
#  ('InN.5', 'TFAP2A_MA0872.1'),
#  ('InN.5', 'ZNF8_MA1718.1'),
#  ('InN.5', 'Foxn1_MA1684.1'),
#  ('InN.5', 'POU2F1::SOX2_MA1962.1'),
#  ('InN.5', 'ZNF669_MA1985.1'),
#  ('InN.5', 'SP1_MA0079.5'),
#  ('InN.5', 'SP2_MA0516.3'),
#  ('InN.5', 'SP4_MA0685.2'),
#  ('InN.5', 'KLF14_MA0740.2'),
#  ('InN.5', 'KLF12_MA0742.2'),
#  ('InN.5', 'KLF10_MA1511.2'),
#  ('InN.5', 'BACH1_MA1633.2'),
#  ('InN.5', 'ZNF213_MA2121.1'),
#  ('InN.5', 'BCL11A_MA2324.1'),
#  ('InN.5', 'ZBED4_MA2328.1'),
#  ('InN.5', 'ZBTB11_MA2329.1'),
#  ('InN.5', 'ZBTB24_MA2330.1'),
#  ('InN.5', 'ZNF35_MA2333.1'),
#  ('InN.5', 'ZNF558_MA2335.1'),
#  ('InN.5', 'BARX2_MA1471.2'),
#  ('InN.5', 'BHLHE23_MA0817.2'),
#  ('InN.5', 'CDX4_MA1473.2'),
#  ('InN.5', 'CEBPG_MA1636.2'),
#  ('InN.5', 'CTCF_MA0139.2'),
#  ('InN.5', 'CTCF_MA1929.2'),
#  ('InN.5', 'CTCF_MA1930.2'),
#  ('InN.5', 'CTCFL_MA1102.3'),
#  ('InN.5', 'HOXB13_MA0901.3'),
#  ('InN.5', 'DBP_MA0639.2'),
#  ('InN.5', 'DMRT3_MA0610.2'),
#  ('InN.5', 'DMRTA1_MA1707.2'),
#  ('InN.5', 'DMRTC2_MA1479.2'),
#  ('InN.5', 'E2F2_MA0864.3'),
#  ('InN.5', 'E2F4_MA0470.3'),
#  ('InN.5', 'E2F6_MA0471.3'),
#  ('InN.5', 'E2F8_MA0865.3'),
#  ('InN.5', 'EGR1_MA0162.5'),
#  ('InN.5', 'EGR3_MA0732.2'),
#  ('InN.5', 'EGR4_MA0733.2'),
#  ('InN.5', 'ELK1_MA0028.3'),
#  ('InN.5', 'TEF_MA0843.2'),
#  ('InN.5', 'ELK3_MA0759.3'),
#  ('InN.5', 'ELK4_MA0076.3'),
#  ('InN.5', 'ETV4_MA0764.4'),
#  ('InN.5', 'ETV5_MA0765.4'),
#  ('InN.5', 'FEV_MA0156.4'),
#  ('InN.5', 'FLI1_MA0475.3'),
#  ('InN.5', 'FOS_MA0476.2'),
#  ('InN.5', 'FOS::JUN_MA0099.4'),
#  ('InN.5', 'FOS::JUNB_MA1134.2'),
#  ('InN.5', 'JUNB_MA0490.3'),
#  ('InN.5', 'FOS::JUND_MA1141.2'),
#  ('InN.5', 'JUND_MA0491.3'),
#  ('InN.5', 'FOSB::JUNB_MA1135.2'),
#  ('InN.5', 'FOSL1_MA0477.3'),
#  ('InN.5', 'FOSL1::JUN_MA1128.2'),
#  ('InN.5', 'FOSL1::JUNB_MA1137.2'),
#  ('InN.5', 'FOSL1::JUND_MA1142.2'),
#  ('InN.5', 'FOSL2::JUN_MA1130.2'),
#  ('InN.5', 'FOSL2::JUNB_MA1138.2'),
#  ('InN.5', 'FOSL2::JUND_MA1144.2'),
#  ('InN.5', 'GATA6_MA1104.3'),
#  ('InN.5', 'HINFP_MA0131.3'),
#  ('InN.5', 'HLF_MA0043.4'),
#  ('InN.5', 'HMBOX1_MA0895.2'),
#  ('InN.5', 'HNF1A_MA0046.3'),
#  ('InN.5', 'HOXA10_MA0899.2'),
#  ('InN.5', 'HOXA4_MA1496.2'),
#  ('InN.5', 'HOXC12_MA0906.2'),
#  ('InN.5', 'HOXD11_MA0908.2'),
#  ('InN.5', 'HOXD9_MA0913.3'),
#  ('InN.5', 'KLF15_MA1513.2'),
#  ('InN.5', 'KLF2_MA1515.2'),
#  ('InN.5', 'KLF3_MA1516.2'),
#  ('InN.5', 'KLF7_MA1959.2'),
#  ('InN.5', 'NFE2_MA0841.2'),
#  ('InN.5', 'MEF2A_MA0052.5'),
#  ('InN.5', 'MEF2C_MA0497.2'),
#  ('InN.5', 'NFIB_MA1643.2'),
#  ('InN.5', 'NFIC_MA1527.2'),
#  ('InN.5', 'NFIL3_MA0025.3'),
#  ('InN.5', 'NFIX_MA1528.2'),
#  ('InN.5', 'ONECUT3_MA0757.2'),
#  ('InN.5', 'PATZ1_MA1961.2'),
#  ('InN.5', 'PBX2_MA1113.3'),
#  ('InN.5', 'PHOX2B_MA0681.3'),
#  ('InN.5', 'PLAGL2_MA1548.2'),
#  ('InN.5', 'POU3F1_MA0786.2'),
#  ('InN.5', 'POU4F1_MA0790.2'),
#  ('InN.5', 'POU4F2_MA0683.2'),
#  ('InN.5', 'POU4F3_MA0791.2'),
#  ('InN.5', 'RFX2_MA0600.3'),
#  ('InN.5', 'RFX5_MA0510.3'),
#  ('InN.5', 'SATB1_MA1963.2'),
#  ('InN.5', 'SP3_MA0746.3'),
#  ('InN.5', 'SP9_MA1564.2'),
#  ('InN.5', 'TCFL5_MA0632.3'),
#  ('InN.5', 'TFAP2A_MA0810.2'),
#  ('InN.5', 'TFAP2A_MA0003.5'),
#  ('InN.5', 'TFAP2B_MA0811.2'),
#  ('InN.5', 'TFAP2B_MA0812.2'),
#  ('InN.5', 'TFAP2C_MA0524.3'),
#  ('InN.5', 'TFAP2E_MA1569.2'),
#  ('InN.5', 'TFDP1_MA1122.2'),
#  ('InN.5', 'TRPS1_MA1970.2'),
#  ('InN.5', 'YY2_MA0748.3'),
#  ('InN.5', 'ZBTB14_MA1650.2'),
#  ('InN.5', 'ZBTB7A_MA0750.3'),
#  ('InN.5', 'ZBTB7C_MA0695.2'),
#  ('InN.5', 'ZFP57_MA1583.2'),
#  ('InN.5', 'ZIC4_MA0751.2'),
#  ('InN.5', 'ZIC5_MA1584.2'),
#  ('InN.5', 'ZKSCAN3_MA1973.2'),
#  ('InN.5', 'ZNF148_MA1653.2'),
#  ('InN.5', 'ZNF211_MA1974.2'),
#  ('InN.5', 'ZNF320_MA1976.2'),
#  ('InN.5', 'ZNF354A_MA1978.2'),
#  ('InN.5', 'ZNF384_MA1125.2'),
#  ('InN.5', 'ZNF417_MA1727.2'),
#  ('InN.5', 'ZNF454_MA1712.2'),
#  ('InN.5', 'ZNF549_MA1728.2'),
#  ('InN.5', 'ZNF574_MA1982.2'),
#  ('InN.5', 'ZNF610_MA1713.2'),
#  ('InN.5', 'ZNF682_MA1599.2'),
#  ('InN.5', 'ZNF692_MA1986.2'),
#  ('InN.5', 'ZNF93_MA1721.2'),
#  ('InN.5', 'Hmga1_MA2124.1'),
#  ('InN.5', 'Zfp961_MA2126.1'),
#  ('InN.5', 'Zbtb2_MA2340.1'),
#  ('InN.5', 'Arid5a_MA0602.2'),
#  ('InN.5', 'Atoh1_MA0461.3'),
#  ('InN.5', 'Jun_MA0489.3'),
#  ('InN.5', 'Dmrt1_MA1603.2'),
#  ('InN.5', 'Dux_MA0611.3'),
#  ('InN.5', 'Gata3_MA0037.5'),
#  ('InN.5', 'Gmeb1_MA0615.2'),
#  ('InN.5', 'Irf1_MA0050.4'),
#  ('InN.5', 'Lhx3_MA0135.2'),
#  ('InN.5', 'Mecom_MA0029.2'),
#  ('InN.5', 'Nkx3-2_MA0122.4'),
#  ('InN.5', 'Nrf1_MA0506.3'),
#  ('InN.5', 'Plagl1_MA1615.2'),
#  ('InN.5', 'Zfx_MA0146.3'),
#  ('InN.5', 'TBP_MA0108.3')]

# %%
import subprocess
from concurrent.futures import ThreadPoolExecutor

# List of cell types
cell_types = ["GN.1", "ExN.1", "InN.5"]  # Add all your cell types here

def run_plotaggregate(cell_tf):
    cell, tf = cell_tf
    tfbs_bed = f"CURRENT/BINDetect_output/{cell}/{tf}/beds/{tf}_all.bed"
    output_file = f"CURRENT/plots/{cell}_{tf}_plotaggregate.pdf"
    title = f"{cell} {tf} Aggregated Signals"

    cmd = [
        "TOBIAS", "PlotAggregate",
        "--signals",
        f"CURRENT/merged_bams/{cell}/footprints/control_footprints.bw",
        f"CURRENT/merged_bams/{cell}/footprints/mdd_footprints.bw",
        "--TFBS", tfbs_bed,
        "--output", output_file,
        "--signal_labels", "control", "mdd",
        "--title", title
    ]

    try:
        subprocess.run(cmd, check=True)
        print(f"✅ Finished: {cell} x {tf}")
    except subprocess.CalledProcessError as e:
        print(f"❌ Error running for {cell} x {tf}: {e}")

# Generate all combinations of cell types and TFs
tasks = [
    ('GN.2', 'Nrf1_MA0506.3'),
]

with ThreadPoolExecutor(max_workers=16) as executor:
        executor.map(run_plotaggregate, tasks)
# Out:
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.234902)
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.234905)
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.234908)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/Neurod2_MA0668.3/beds/Neurod2_MA0668.3_all.bed --output CURRENT/plots/GN.1_Neurod2_MA0668.3_plotaggregate.pdf --signal_labels control mdd --title GN.1 Neurod2_MA0668.3 Aggregated Signals
#
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/ZNF354A_MA1978.2/beds/ZNF354A_MA1978.2_all.bed --output CURRENT/plots/GN.1_ZNF354A_MA1978.2_plotaggregate.pdf --signal_labels control mdd --title GN.1 ZNF354A_MA1978.2 Aggregated Signals
#
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/MEF2A_MA0052.5/beds/MEF2A_MA0052.5_all.bed --output CURRENT/plots/GN.1_MEF2A_MA0052.5_plotaggregate.pdf --signal_labels control mdd --title GN.1 MEF2A_MA0052.5 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/Neurod2_MA0668.3/beds/Neurod2_MA0668.3_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_Neurod2_MA0668.3_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 Neurod2_MA0668.3 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.1_Neurod2_MA0668.3_plotaggregate.pdf
#
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/MEF2A_MA0052.5/beds/MEF2A_MA0052.5_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_MEF2A_MA0052.5_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 MEF2A_MA0052.5 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/ZNF354A_MA1978.2/beds/ZNF354A_MA1978.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_ZNF354A_MA1978.2_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 ZNF354A_MA1978.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # ----- Output files -----
# # CURRENT/plots/GN.1_MEF2A_MA0052.5_plotaggregate.pdf
# # CURRENT/plots/GN.1_ZNF354A_MA1978.2_plotaggregate.pdf
#
#
#
#
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.235490)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.2/footprints/control_footprints.bw CURRENT/merged_bams/GN.2/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.2/Nrf1_MA0506.3.2/beds/Nrf1_MA0506.3.2_all.bed --output CURRENT/plots/GN.2_Nrf1_MA0506.3.2_plotaggregate.pdf --signal_labels control mdd --title GN.2 Nrf1_MA0506.3.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.2/Nrf1_MA0506.3.2/beds/Nrf1_MA0506.3.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.2/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.2/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.2_Nrf1_MA0506.3.2_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.2 Nrf1_MA0506.3.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.2_Nrf1_MA0506.3.2_plotaggregate.pdf
#
#
# 2025-04-23 13:50:59 (2258546) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258560) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258546) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258560) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258541) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258541) [INFO]	Reading information from .bed-files
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.239009)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/ExN.1/footprints/control_footprints.bw CURRENT/merged_bams/ExN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/ExN.1/ZNF610_MA1713.2/beds/ZNF610_MA1713.2_all.bed --output CURRENT/plots/ExN.1_ZNF610_MA1713.2_plotaggregate.pdf --signal_labels control mdd --title ExN.1 ZNF610_MA1713.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/ExN.1/ZNF610_MA1713.2/beds/ZNF610_MA1713.2_all.bed']
# # signals:	['CURRENT/merged_bams/ExN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/ExN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/ExN.1_ZNF610_MA1713.2_plotaggregate.pdf
# # output_txt:	None
# # title:	ExN.1 ZNF610_MA1713.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/ExN.1_ZNF610_MA1713.2_plotaggregate.pdf
#
#
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.240623)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.240667)
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/InN.5/footprints/control_footprints.bw CURRENT/merged_bams/InN.5/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/InN.5/MEF2A_MA0052.5/beds/MEF2A_MA0052.5_all.bed --output CURRENT/plots/InN.5_MEF2A_MA0052.5_plotaggregate.pdf --signal_labels control mdd --title InN.5 MEF2A_MA0052.5 Aggregated Signals
#
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/POU4F1_MA0790.2/beds/POU4F1_MA0790.2_all.bed --output CURRENT/plots/GN.1_POU4F1_MA0790.2_plotaggregate.pdf --signal_labels control mdd --title GN.1 POU4F1_MA0790.2 Aggregated Signals
#
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.240799)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/OLIG2_MA0678.1/beds/OLIG2_MA0678.1_all.bed --output CURRENT/plots/GN.1_OLIG2_MA0678.1_plotaggregate.pdf --signal_labels control mdd --title GN.1 OLIG2_MA0678.1 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/InN.5/MEF2A_MA0052.5/beds/MEF2A_MA0052.5_all.bed']
# # signals:	['CURRENT/merged_bams/InN.5/footprints/control_footprints.bw', 'CURRENT/merged_bams/InN.5/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/InN.5_MEF2A_MA0052.5_plotaggregate.pdf
# # output_txt:	None
# # title:	InN.5 MEF2A_MA0052.5 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/InN.5_MEF2A_MA0052.5_plotaggregate.pdf
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/POU4F1_MA0790.2/beds/POU4F1_MA0790.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_POU4F1_MA0790.2_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 POU4F1_MA0790.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.1_POU4F1_MA0790.2_plotaggregate.pdf
#
#
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.241099)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/FOSBJUNB_MA1135.2/beds/FOSBJUNB_MA1135.2_all.bed --output CURRENT/plots/GN.1_FOSBJUNB_MA1135.2_plotaggregate.pdf --signal_labels control mdd --title GN.1 FOSBJUNB_MA1135.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/OLIG2_MA0678.1/beds/OLIG2_MA0678.1_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_OLIG2_MA0678.1_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 OLIG2_MA0678.1 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.1_OLIG2_MA0678.1_plotaggregate.pdf
#
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/FOSBJUNB_MA1135.2/beds/FOSBJUNB_MA1135.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_FOSBJUNB_MA1135.2_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 FOSBJUNB_MA1135.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.1_FOSBJUNB_MA1135.2_plotaggregate.pdf
#
#
# 2025-04-23 13:50:59 (2258550) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258550) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258558) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258558) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258544) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258544) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258554) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258554) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258556) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258556) [INFO]	Reading information from .bed-files
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.243473)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/ExN.1/footprints/control_footprints.bw CURRENT/merged_bams/ExN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/ExN.1/PATZ1_MA1961.2/beds/PATZ1_MA1961.2_all.bed --output CURRENT/plots/ExN.1_PATZ1_MA1961.2_plotaggregate.pdf --signal_labels control mdd --title ExN.1 PATZ1_MA1961.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/ExN.1/PATZ1_MA1961.2/beds/PATZ1_MA1961.2_all.bed']
# # signals:	['CURRENT/merged_bams/ExN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/ExN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/ExN.1_PATZ1_MA1961.2_plotaggregate.pdf
# # output_txt:	None
# # title:	ExN.1 PATZ1_MA1961.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/ExN.1_PATZ1_MA1961.2_plotaggregate.pdf
#
#
# 2025-04-23 13:50:59 (2258548) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258548) [INFO]	Reading information from .bed-files
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.248001)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/GN.1/footprints/control_footprints.bw CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/GN.1/Neurod2_MA1993.2/beds/Neurod2_MA1993.2_all.bed --output CURRENT/plots/GN.1_Neurod2_MA1993.2_plotaggregate.pdf --signal_labels control mdd --title GN.1 Neurod2_MA1993.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/GN.1/Neurod2_MA1993.2/beds/Neurod2_MA1993.2_all.bed']
# # signals:	['CURRENT/merged_bams/GN.1/footprints/control_footprints.bw', 'CURRENT/merged_bams/GN.1/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/GN.1_Neurod2_MA1993.2_plotaggregate.pdf
# # output_txt:	None
# # title:	GN.1 Neurod2_MA1993.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/GN.1_Neurod2_MA1993.2_plotaggregate.pdf
#
#
# 2025-04-23 13:50:59 (2258561) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258561) [INFO]	Reading information from .bed-files
# # TOBIAS 0.17.1 PlotAggregate (run started 2025-04-23 13:50:59.251864)
# # Working directory: /groups/mb928_gp/mp4486/tobias
# # Command line call: TOBIAS PlotAggregate --signals CURRENT/merged_bams/InN.5/footprints/control_footprints.bw CURRENT/merged_bams/InN.5/footprints/mdd_footprints.bw --TFBS CURRENT/BINDetect_output/InN.5/ZNF354A_MA1978.2/beds/ZNF354A_MA1978.2_all.bed --output CURRENT/plots/InN.5_ZNF354A_MA1978.2_plotaggregate.pdf --signal_labels control mdd --title InN.5 ZNF354A_MA1978.2 Aggregated Signals
#
# # ----- Input parameters -----
# # TFBS:	['CURRENT/BINDetect_output/InN.5/ZNF354A_MA1978.2/beds/ZNF354A_MA1978.2_all.bed']
# # signals:	['CURRENT/merged_bams/InN.5/footprints/control_footprints.bw', 'CURRENT/merged_bams/InN.5/footprints/mdd_footprints.bw']
# # regions:	[]
# # whitelist:	[]
# # blacklist:	[]
# # output:	CURRENT/plots/InN.5_ZNF354A_MA1978.2_plotaggregate.pdf
# # output_txt:	None
# # title:	InN.5 ZNF354A_MA1978.2 Aggregated Signals
# # flank:	60
# # TFBS_labels:	None
# # signal_labels:	['control', 'mdd']
# # region_labels:	None
# # share_y:	none
# # normalize:	False
# # negate:	False
# # smooth:	1
# # log_transform:	False
# # plot_boundaries:	False
# # signal_on_x:	False
# # remove_outliers:	1
# # verbosity:	3
#
#
# # ----- Output files -----
# # CURRENT/plots/InN.5_ZNF354A_MA1978.2_plotaggregate.pdf
#
#
# 2025-04-23 13:50:59 (2258540) [INFO]	---- Processing input ----
# 2025-04-23 13:50:59 (2258540) [INFO]	Reading information from .bed-files
# 2025-04-23 13:50:59 (2258558) [STATS]	COUNT OLIG2_MA0678.1_all: 17416 sites
# 2025-04-23 13:50:59 (2258558) [INFO]	Reading signal from bigwigs
# 2025-04-23 13:50:59 (2258558) [INFO]	- Reading signal from control
# 2025-04-23 13:50:59 (2258554) [STATS]	COUNT FOSBJUNB_MA1135.2_all: 34467 sites
# 2025-04-23 13:50:59 (2258554) [INFO]	Reading signal from bigwigs
# 2025-04-23 13:50:59 (2258554) [INFO]	- Reading signal from control
# ERROR: File "CURRENT/BINDetect_output/GN.2/Nrf1_MA0506.3.2/beds/Nrf1_MA0506.3.2_all.bed" does not exists
# 2025-04-23 13:50:59 (2258544) [STATS]	COUNT MEF2A_MA0052.5_all: 37957 sites
# 2025-04-23 13:50:59 (2258544) [INFO]	Reading signal from bigwigs
# 2025-04-23 13:50:59 (2258544) [INFO]	- Reading signal from control
# 2025-04-23 13:50:59 (2258556) [STATS]	COUNT POU4F1_MA0790.2_all: 41889 sites
# 2025-04-23 13:50:59 (2258556) [INFO]	Reading signal from bigwigs
# 2025-04-23 13:50:59 (2258556) [INFO]	- Reading signal from control
# 2025-04-23 13:50:59 (2258540) [STATS]	COUNT ZNF354A_MA1978.2_all: 45823 sites
# 2025-04-23 13:50:59 (2258540) [INFO]	Reading signal from bigwigs
# 2025-04-23 13:50:59 (2
[INFO]	Finished PlotAggregate run (total time elapsed: 0:00:17.962012)
# ✅ Finished: GN.1 x Neurod2_MA1993.2
# 2025-04-23 13:51:20 (2258548) [INFO]	- Reading signal from mdd
# 2025-04-23 13:51:41 (2258548) [INFO]	Calculating aggregate signals
#
# 2025-04-23 13:51:42 (2258548) [INFO]	---- Analysis ----
# 2025-04-23 13:51:42 (2258548) [INFO]	Calculating footprint depth measure
# 2025-04-23 13:51:42 (2258548) [INFO]	FPD (signal,regions): footprint_width baseline middle FPD
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 10 0.32053 0.31897 -0.00156
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 12 0.32055 0.31903 -0.00152
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 14 0.32061 0.31885 -0.00176
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 16 0.32064 0.31883 -0.00181
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 18 0.32069 0.31878 -0.00191
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 20 0.32070 0.31889 -0.00181
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 22 0.32071 0.31904 -0.00167
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 24 0.32070 0.31919 -0.00151
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 26 0.32069 0.31936 -0.00133
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 28 0.32066 0.31955 -0.00111
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 30 0.32062 0.31975 -0.00086
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 32 0.32056 0.31996 -0.00060
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 34 0.32049 0.32016 -0.00033
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 36 0.32042 0.32035 -0.00007
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 38 0.32034 0.32052 0.00018
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 40 0.32026 0.32068 0.00041
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 42 0.32018 0.32081 0.00063
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 44 0.32009 0.32093 0.00084
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 46 0.32000 0.32104 0.00104
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (control,PATZ1_MA1961.2_all): 48 0.31991 0.32114 0.00123
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 10 0.30637 0.30492 -0.00145
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 12 0.30639 0.30498 -0.00141
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 14 0.30644 0.30481 -0.00163
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 16 0.30647 0.30479 -0.00168
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 18 0.30651 0.30474 -0.00177
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 20 0.30653 0.30484 -0.00169
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 22 0.30653 0.30498 -0.00156
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 24 0.30653 0.30512 -0.00141
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 26 0.30652 0.30527 -0.00124
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 28 0.30649 0.30545 -0.00104
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 30 0.30645 0.30564 -0.00081
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 32 0.30640 0.30583 -0.00057
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 34 0.30634 0.30602 -0.00032
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 36 0.30627 0.30619 -0.00008
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 38 0.30620 0.30635 0.00015
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 40 0.30612 0.30649 0.00037
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 42 0.30605 0.30662 0.00057
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 44 0.30597 0.30673 0.00076
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 46 0.30588 0.30683 0.00094
# 2025-04-23 13:51:42 (2258548) [STATS]	FPD (mdd,PATZ1_MA1961.2_all): 48 0.30580 0.30692 0.00112
#
# 2025-04-23 13:51:42 (2258548) [INFO]	Calculating measures for comparing pairwise aggregates
# 2025-04-23 13:51:42 (2258548) [INFO]	CORRELATION (signal1,region1) VS (signal2,region2): PEARSONR	SUM_DIFF
# 2025-04-23 13:51:42 (2258548) [STATS]	CORRELATION (control,PATZ1_MA1961.2_all) VS (mdd,PATZ1_MA1961.2_all): 0.99986	1.69837
#
# 2025-04-23 13:51:42 (2258548) [INFO]	---- Plotting aggregates ----
# 2025-04-23 13:51:42 (2258548) [INFO]	Setting up plotting grid
# 2025-04-23 13:51:42 (2258548) [INFO]	Plotting regions PATZ1_MA1961.2_all from signal control
# 2025-04-23 13:51:42 (2258548) [INFO]	Plotting regions PATZ1_MA1961.2_all from signal mdd
# 2025-04-23 13:51:42 (2258548) [INFO]	Adjusting final details
#
# 2025-04-23 13:51:42 (2258548) [INFO]	Finished PlotAggregate run (total time elapsed: 0:00:43.259819)
# ✅ Finished: ExN.1 x PATZ1_MA1961.2

# %%
# Out of all these, aggregate the spreadsheets

from collections import defaultdict

cell_types = ['ExN.1', 'GN.1', 'GN.2', 'InN.5']

# Read the RTF and parse TFs for each cell type
celltype_to_tfs = defaultdict(list)

with open('CURRENT/TFs_to_use.txt', 'r') as f:
    current_celltype = None
    for line in f:
        line = line.strip()
        if not line:
            continue
     
        if line in cell_types:  
            current_celltype = line
        else:
            tf = line.strip()
            if current_celltype is not None:
                celltype_to_tfs[current_celltype].append(tf)
            else:
                print(f"⚠️ Found TF without cell type: {tf}")
print(f"Parsed cell types: {list(celltype_to_tfs.keys())}")
# Out:
# Parsed cell types: ['ExN.1', 'GN.1', 'GN.2', 'InN.5']

# %%
import os
output_dir = "combined_TF_hits_per_celltype"
os.makedirs(output_dir, exist_ok=True)

celltype_dfs = {}

for celltype, tf_list in celltype_to_tfs.items():
    print(f"\nProcessing {celltype} with {len(tf_list)} TFs...")
    dfs = []
    cell_dir = os.path.join('CURRENT/BINDetect_output', celltype)
    
    for tf in tf_list:
        csv_file = os.path.join(cell_dir,tf,f"{tf}_overview.txt")
        if os.path.exists(csv_file):
            df = pd.read_csv(csv_file, sep="\t")
            dfs.append(df)
        else:
            print(f"⚠️ Missing: {csv_file}")
    
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        celltype_dfs[celltype] = combined_df
        combined_df.to_csv(os.path.join(output_dir, f"{celltype}_combined.csv"), index=False)
    else:
        print(f"❗ No TF files found for {celltype}!")
# Out:
# Processing ExN.1 with 48 TFs...
#
# Processing GN.1 with 63 TFs...
#
# Processing GN.2 with 3 TFs...
#
# Processing InN.5 with 47 TFs...

# %%
celltype_dfs['ExN.1']
# Out:
#            TFBS_chr  TFBS_start  TFBS_end       TFBS_name  TFBS_score  \
# 0        GL000194.1       55947     55955  CTCFL_MA1102.3     8.76966
# 1        GL000194.1       58435     58443  CTCFL_MA1102.3     7.56089
# 2        GL000194.1       68032     68040  CTCFL_MA1102.3     7.56089
# 3        GL000194.1       68142     68150  CTCFL_MA1102.3     8.76966
# 4        GL000194.1       71739     71747  CTCFL_MA1102.3     7.34821
# ...             ...         ...       ...             ...         ...
# 4028396        chrY    19077139  19077153   ZIC1_MA0696.1     6.61887
# 4028397        chrY    19567593  19567607   ZIC1_MA0696.1     4.72802
# 4028398        chrY    19744381  19744395   ZIC1_MA0696.1     5.61109
# 4028399        chrY    20978937  20978951   ZIC1_MA0696.1     5.80581
# 4028400        chrY    26670798  26670812   ZIC1_MA0696.1     7.33781
#
#         TFBS_strand    peak_chr  peak_start  peak_end      peak_id peak_score  \
# 0                 -  GL000194.1       55808     56722       peak_6          .
# 1                 +  GL000194.1       58351     58695       peak_8          .
# 2                 -  GL000194.1       67958     68971      peak_11          .
# 3                 +  GL000194.1       67958     68971      peak_11          .
# 4                 -  GL000194.1       71707     71927      peak_12          .
# ...             ...         ...         ...       ...          ...        ...
# 4028396           -        chrY    19075515  19078146  peak_229899          .
# 4028397           -        chrY    19566500  19568218  peak_229901          .
# 4028398           -        chrY    19743926  19745415  peak_229907          .
# 4028399           -        chrY    20978846  20979298  peak_229918          .
# 4028400           -        chrY    26670181  26671740  peak_229922          .
#
#         peak_strand          gene_id gene_name  ExN.1MDD_score  \
# 0                 .              NaN       NaN         0.04061
# 1                 .              NaN       NaN         0.03660
# 2                 .              NaN       NaN         0.03447
# 3                 .              NaN       NaN         0.03511
# 4                 .              NaN       NaN         0.03614
# ...             ...              ...       ...             ...
# 4028396           .  ENSG00000310485       NaN         0.22560
# 4028397           .  ENSG00000131002    TXLNGY         0.20418
# 4028398           .  ENSG00000288049       NaN         0.05755
# 4028399           .              NaN       NaN         0.06520
# 4028400           .              NaN       NaN         0.13184
#
#          ExN.1CTRL_score  ExN.1MDD_bound  ExN.1CTRL_bound  \
# 0                0.04195               0                0
# 1                0.03447               0                0
# 2                0.03158               0                0
# 3                0.02238               0                0
# 4                0.02471               0                0
# ...                  ...             ...              ...
# 4028396          0.18743               1                0
# 4028397          0.22325               0                1
# 4028398          0.04629               0                0
# 4028399          0.08041               0                0
# 4028400          0.13802               0                0
#
#          ExN.1MDD_ExN.1CTRL_log2fc
# 0                         -0.02634
# 1                          0.04542
# 2                          0.06401
# 3                          0.30282
# 4                          0.26437
# ...                            ...
# 4028396                    0.23125
# 4028397                   -0.11197
# 4028398                    0.19358
# 4028399                   -0.20949
# 4028400                   -0.05338
#
# [4028401 rows x 19 columns]

# %%
de_rna = pd.read_csv('../Multiome_process/DE_RESULTS/dif_expression_mdd_vs_ctrl_leiden_annotations.csv')
de_atac = pd.read_csv('../Multiome_process/DE_RESULTS/DE_from_predicted_gene_activity_mdd_vs_ctrl.csv')

de_rna = de_rna[de_rna['adj.P.Val'] < 0.05]
de_atac = de_atac[de_atac['adj.P.Val'] < 0.05]

# %%
# Out:
#           Unnamed: 0     logFC   AveExpr         t       P.Value  adj.P.Val  \
# 0          LINC02315  2.519347  2.738877  6.642613  7.553579e-09   0.000120
# 1         FP671120.4  1.427939  3.204372  5.122715  2.933403e-06   0.023344
# 2              ACOT1  1.670513  1.890780  4.815490  9.218714e-06   0.041702
# 3          MIR2052HG  0.566993  6.254350  4.670235  1.568618e-05   0.041702
# 4             CACNB2 -0.468203  9.722582 -4.636752  1.771383e-05   0.041702
# ...              ...       ...       ...       ...           ...        ...
# 459427    TNFRSF1925 -0.748854  4.613302 -5.149835  2.514253e-06   0.008209
# 459428  AC090403.116 -2.053451  3.900041 -4.881804  6.906411e-06   0.018791
# 459429   MIR3681HG23 -0.724127  8.138444 -4.693994  1.383843e-05   0.028820
# 459430  AC005906.227 -0.536407  6.102415 -4.688440  1.412333e-05   0.028820
# 459431     CCDC12527  0.478231  4.727236  4.505711  2.744914e-05   0.049790
#
#                B cell_type        gene
# 0       7.801319   Astro.1   LINC02315
# 1       3.708431   Astro.1  FP671120.4
# 2       2.200764   Astro.1       ACOT1
# 3       2.894991   Astro.1   MIR2052HG
# 4       2.754153   Astro.1      CACNB2
# ...          ...       ...         ...
# 459427  4.401316       OPC    TNFRSF19
# 459428  3.340676       OPC  AC090403.1
# 459429  2.923820       OPC   MIR3681HG
# 459430  2.993036       OPC  AC005906.2
# 459431  2.365940       OPC     CCDC125
#
# [486 rows x 9 columns]

# %%
for c in cell_types:
    df = celltype_dfs[c]
    rna = de_rna[de_rna['cell_type'] == c]
    atac = de_atac[de_atac['cell_type'] == c]
    overlap_rna = list(set(df['gene_name']) & set(rna['gene']))
    overlap_atac = list(set(df['gene_name']) & set(atac['gene']))

    overlaps = list(set(overlap_rna + overlap_atac))
    print(len(overlaps))
    celltype_dfs[c] = df[df['gene_name'].isin(overlaps)]
# Out:
# 107
# 1487
# 25
# 25

# %%
for c in cell_types:
    df = celltype_dfs[c]
    # df = df[(df[f"{c}MDD_bound"]==0) | (df[f"{c}CTRL_bound"]==0)]
    
    # rna = de_rna[de_rna['cell_type'] == c]
    # overlap_rna = list(set(df['gene_name']) & set(rna['gene']))
    
    # df = df[df['gene_name'].isin(overlap_rna)]
    # celltype_dfs[c] = df    
    df.to_csv(os.path.join('combined_TF_hits_per_celltype/', f"{c}_combined_filtered_final.csv"), index=False)

# %%
cell_types = ['GN.1', 'GN.2', 'ExN.1', 'InN.5']
celltype_dfs = {}

for c in cell_types:
    df = pd.read_csv(os.path.join('combined_TF_hits_per_celltype/', f"{c}_combined_filtered_final.csv"))
    celltype_dfs[c] = df

len(celltype_dfs)
# Out:
# 4

# %%
celltype_dfs['GN.1'].sort_values('GN.1MDD_GN.1CTRL_log2fc', ascending=False).tail(20)
# Out:
#        TFBS_chr  TFBS_start   TFBS_end        TFBS_name  TFBS_score  \
# 114567     chr1   228635401  228635412  ZNF682_MA1599.2     7.14135
# 111881     chr1   228635349  228635359  ZNF610_MA1713.2     7.04504
# 40792      chr1   228635372  228635383   KLF16_MA0741.1     8.37561
# 62089      chr1   228635372  228635383     SP3_MA0746.3     8.49302
# 24853      chr1   228635373  228635382   KLF10_MA1511.2     7.05394
# 20209      chr1   228635373  228635382    KLF6_MA1517.2     8.29170
# 64734      chr1   228635373  228635382     SP4_MA0685.2     6.26553
# 28141      chr1   228635373  228635383   KLF11_MA1512.2     9.08053
# 22002      chr1   228635373  228635381    KLF7_MA1959.2     7.70673
# 67687      chr1   228635373  228635383     SP9_MA1564.2     9.10381
# 92957      chr1   228621002  228621016   ZNF93_MA1721.2     9.49880
# 89801      chr1   228620995  228621009    ZIC1_MA0696.1     5.87961
# 46255      chr1   228621011  228621022   PATZ1_MA1961.2     7.84183
# 51643      chr1   228621017  228621031   PLAG1_MA0163.1     4.53364
# 28140      chr1   228621017  228621027   KLF11_MA1512.2     7.58525
# 85084      chr1   228621027  228621035  ZBTB14_MA1650.2     7.63674
# 95837      chr1   228621082  228621092  ZNF148_MA1653.2     7.61798
# 100229     chr1   228621082  228621092  ZNF281_MA1630.3    11.28261
# 100228     chr1   228621056  228621066  ZNF281_MA1630.3     5.86162
# 109311     chr1   228621045  228621059  ZNF530_MA1981.2     6.79860
#
#        TFBS_strand peak_chr  peak_start   peak_end     peak_id peak_score  \
# 114567           +     chr1   228635126  228635663  peak_14349          .
# 111881           +     chr1   228635126  228635663  peak_14349          .
# 40792            +     chr1   228635126  228635663  peak_14349          .
# 62089            +     chr1   228635126  228635663  peak_14349          .
# 24853            -     chr1   228635126  228635663  peak_14349          .
# 20209            +     chr1   228635126  228635663  peak_14349          .
# 64734            -     chr1   228635126  228635663  peak_14349          .
# 28141            +     chr1   228635126  228635663  peak_14349          .
# 22002            -     chr1   228635126  228635663  peak_14349          .
# 67687            +     chr1   228635126  228635663  peak_14349          .
# 92957            +     chr1   228620689  228621092  peak_14348          .
# 89801            +     chr1   228620689  228621092  peak_14348          .
# 46255            +     chr1   228620689  228621092  peak_14348          .
# 51643            +     chr1   228620689  228621092  peak_14348          .
# 28140            -     chr1   228620689  228621092  peak_14348          .
# 85084            -     chr1   228620689  228621092  peak_14348          .
# 95837            -     chr1   228620689  228621092  peak_14348          .
# 100229           +     chr1   228620689  228621092  peak_14348          .
# 100228           +     chr1   228620689  228621092  peak_14348          .
# 109311           +     chr1   228620689  228621092  peak_14348          .
#
#        peak_strand          gene_id gene_name  GN.1MDD_score  GN.1CTRL_score  \
# 114567           .  ENSG00000199270   RNA5S12        0.24288         0.54277
# 111881           .  ENSG00000199270   RNA5S12        0.17391         0.40497
# 40792            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 62089            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 24853            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 20209            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 64734            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 28141            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 22002            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 67687            .  ENSG00000199270   RNA5S12        0.17391         0.41826
# 92957            .  ENSG00000200624    RNA5S6        0.18540         0.44328
# 89801            .  ENSG00000200624    RNA5S6        0.18540         0.44328
# 46255            .  ENSG00000200624    RNA5S6        0.18540         0.44956
# 51643            .  ENSG00000200624    RNA5S6        0.18540         0.45681
# 28140            .  ENSG00000200624    RNA5S6        0.18540         0.45681
# 85084            .  ENSG00000200624    RNA5S6        0.18540         0.45763
# 95837            .  ENSG00000200624    RNA5S6        0.19226         0.48154
# 100229           .  ENSG00000200624    RNA5S6        0.19226         0.48154
# 100228           .  ENSG00000200624    RNA5S6        0.24188         0.59963
# 109311           .  ENSG00000200624    RNA5S6        0.16855         0.50292
#
#         GN.1MDD_bound  GN.1CTRL_bound  GN.1MDD_GN.1CTRL_log2fc
# 114567              0               1                 -1.04151
# 111881              0               1                 -1.05507
# 40792               0               1                 -1.09748
# 62089               0               1                 -1.09748
# 24853               0               1                 -1.09748
# 20209               0               1                 -1.09748
# 64734               0               1                 -1.09748
# 28141               0               1                 -1.09748
# 22002               0               1                 -1.09748
# 67687               0               1                 -1.09748
# 92957               0               1                 -1.09877
# 89801               0               1                 -1.09877
# 46255               0               1                 -1.11738
# 51643               0               1                 -1.13857
# 28140               0               1                 -1.13857
# 85084               0               1                 -1.14095
# 95837               0               1                 -1.16542
# 100229              0               1                 -1.16542
# 100228              0               1                 -1.18082
# 109311              0               1                 -1.37835

# %%
celltype_dfs['GN.1'].value_counts(['TFBS_name','gene_name']).to_frame().head(15)
# Out:
#                            count
# TFBS_name       gene_name
# ZNF454_MA1712.2 DAP            6
# PATZ1_MA1961.2  DAP            4
# KLF15_MA1513.2  DAP            4
# ZBED4_MA2328.1  NETO2          4
# ZNF530_MA1981.2 SUSD4          3
# PATZ1_MA1961.2  DPF3           3
# ZBED4_MA2328.1  ZMIZ1          3
# ZNF93_MA1721.2  DAP            3
# KLF12_MA0742.2  DAP            3
# E2F6_MA0471.3   HNRNPR         3
# KLF2_MA1515.2   DAP            3
# SP3_MA0746.3    DPF3           3
# KLF4_MA0039.5   DAP            3
# ZNF530_MA1981.2 HNRNPR         3
# ZBED4_MA2328.1  DPF3           3

# %%
celltype_dfs['GN.1'].value_counts(['TFBS_name','gene_name'])
# Out:
# TFBS_name        gene_name
# ZNF454_MA1712.2  DAP          6
# PATZ1_MA1961.2   DAP          4
# KLF15_MA1513.2   DAP          4
# ZBED4_MA2328.1   NETO2        4
# ZNF530_MA1981.2  SUSD4        3
#                              ..
# PLAG1_MA0163.1   AKAP5        1
#                  BRINP3       1
#                  FADS3        1
#                  FAM118A      1
# PATZ1_MA1961.2   RUNX1T1      1
# Name: count, Length: 815, dtype: int64

# %%
gn1_stk = celltype_dfs['GN.1'][celltype_dfs['GN.1']['gene_name'] == 'STK33']
stk_regions = gn1_stk[['TFBS_chr', 'TFBS_start', 'TFBS_end']].astype(str).agg('-'.join, axis=1)
stk_regions.to_csv('CURRENT/highlight_regions/DAP.csv')

# %%
gn1_dap['highlight_region'] = gn1_dap[['TFBS_chr', 'TFBS_start', 'TFBS_end']].astype(str).agg('-'.join, axis=1)
# Out:
# /tmp/mp4486/ipykernel_2729134/3649905261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gn1_dap['highlight_region'] = gn1_dap[['TFBS_chr', 'TFBS_start', 'TFBS_end']].astype(str).agg('-'.join, axis=1)

# %%
gn1_dap = gn1_dap[(gn1_dap['TFBS_name'] == 'ZNF454_MA1712.2') | (gn1_dap['TFBS_name'] == 'PATZ1_MA1961.2') | (gn1_dap['TFBS_name'] == 'KLF15_MA1513.2')]

# %%
gn1_dap[['TFBS_name', 'gene_name', 'highlight_region', 'GN.1MDD_bound', 'GN.1MDD_GN.1CTRL_log2fc']]
# Out:
#                TFBS_name gene_name        highlight_region  GN.1MDD_bound  \
# 1276058   KLF15_MA1513.2       DAP  chr5-10760870-10760878              1
# 1276059   KLF15_MA1513.2       DAP  chr5-10760881-10760889              1
# 1276060   KLF15_MA1513.2       DAP  chr5-10760940-10760948              1
# 1276067   KLF15_MA1513.2       DAP  chr5-10761406-10761414              1
# 1613861   PATZ1_MA1961.2       DAP  chr5-10760869-10760880              1
# 1613862   PATZ1_MA1961.2       DAP  chr5-10760939-10760950              1
# 1613867   PATZ1_MA1961.2       DAP  chr5-10761404-10761415              1
# 1613868   PATZ1_MA1961.2       DAP  chr5-10761416-10761427              1
# 3670971  ZNF454_MA1712.2       DAP  chr5-10760726-10760743              1
# 3670972  ZNF454_MA1712.2       DAP  chr5-10760769-10760786              0
# 3670974  ZNF454_MA1712.2       DAP  chr5-10760867-10760884              1
# 3670975  ZNF454_MA1712.2       DAP  chr5-10760888-10760905              1
# 3670976  ZNF454_MA1712.2       DAP  chr5-10760943-10760960              1
# 3670977  ZNF454_MA1712.2       DAP  chr5-10760968-10760985              0
#
#          GN.1MDD_GN.1CTRL_log2fc
# 1276058                  0.15424
# 1276059                  0.14383
# 1276060                  0.42277
# 1276067                  0.33202
# 1613861                  0.15424
# 1613862                  0.42277
# 1613867                  0.33202
# 1613868                  0.33202
# 3670971                  0.20824
# 3670972                 -0.10754
# 3670974                  0.15149
# 3670975                  0.14383
# 3670976                  0.37856
# 3670977                 -0.12855

# %%
gn1_stk
# Out:
#     TFBS_chr  TFBS_start  TFBS_end        TFBS_name  TFBS_score TFBS_strand  \
# 116    chr11     8612754   8612762    KLF4_MA0039.5     7.17966           +
# 729    chr11     8612738   8612752   ZNF93_MA1721.2     9.86667           +
# 932    chr11     8612681   8612692  ZNF682_MA1599.2     7.26837           +
#
#     peak_chr  peak_start  peak_end     peak_id peak_score peak_strand  \
# 116    chr11     8612218   8613143  peak_24945          .           .
# 729    chr11     8612218   8613143  peak_24945          .           .
# 932    chr11     8612218   8613143  peak_24945          .           .
#
#              gene_id gene_name  GN.1MDD_score  GN.1CTRL_score  GN.1MDD_bound  \
# 116  ENSG00000130413     STK33        0.32035         0.15041              1
# 729  ENSG00000130413     STK33        0.35848         0.15722              1
# 932  ENSG00000130413     STK33        0.29257         0.14367              1
#
#      GN.1CTRL_bound  GN.1MDD_GN.1CTRL_log2fc
# 116               0                  0.91862
# 729               0                  1.01297
# 932               0                  0.85490

# %% [markdown]
# ## Finding the TFs and genes with highest logFC in RNA DEGs

# %%
gn1_genes = list(set(celltype_dfs['GN.1']['gene_name']))
gn2_genes = list(set(celltype_dfs['GN.2']['gene_name']))
ex1_genes = list(set(celltype_dfs['ExN.1']['gene_name']))
in5_genes = list(set(celltype_dfs['InN.5']['gene_name']))

# %%
gn1_footprints_degs = de_rna[(de_rna['gene'].isin(gn1_genes)) & (de_rna['cell_type']=='GN.1')]
gn2_footprints_degs = de_rna[(de_rna['gene'].isin(gn2_genes)) & (de_rna['cell_type']=='GN.2')]
ex1_footprints_degs = de_rna[(de_rna['gene'].isin(ex1_genes)) & (de_rna['cell_type']=='ExN.1')]
in5_footprints_degs = de_rna[(de_rna['gene'].isin(in5_genes)) & (de_rna['cell_type']=='InN.5')]

# %%
gn2_footprints_degs
# Out:
#         Unnamed: 0     logFC   AveExpr         t   P.Value  adj.P.Val  \
# 238363  ZDHHC11B13 -0.942788  4.233546 -5.073574  0.000004   0.013788
#
#                B cell_type      gene
# 238363  3.706624      GN.2  ZDHHC11B

# %%
celltype_dfs['GN.1']=celltype_dfs['GN.1'].merge(gn1_footprints_degs[['gene', 'logFC', 'AveExpr', 'adj.P.Val']],
                                                 how='left',
                                                 left_on = 'gene_name', right_on='gene')

celltype_dfs['GN.2']=celltype_dfs['GN.2'].merge(gn2_footprints_degs[['gene', 'logFC', 'AveExpr', 'adj.P.Val']],
                                                 how='left',
                                                 left_on = 'gene_name', right_on='gene')

celltype_dfs['ExN.1']=celltype_dfs['ExN.1'].merge(ex1_footprints_degs[['gene', 'logFC', 'AveExpr', 'adj.P.Val']],
                                                 how='left',
                                                 left_on = 'gene_name', right_on='gene')

celltype_dfs['InN.5']=celltype_dfs['InN.5'].merge(in5_footprints_degs[['gene', 'logFC', 'AveExpr', 'adj.P.Val']],
                                                 how='left',
                                                 left_on = 'gene_name', right_on='gene')

# %%
set(celltype_dfs['GN.1']['gene'])
# Out:
# {'AKAP5',
#  'ARHGAP28',
#  'BLCAP',
#  'BRI3BP',
#  'BRINP3',
#  'BTBD16',
#  'C1RL',
#  'CCDC170',
#  'CCND2',
#  'CCND2-AS1',
#  'CD99L2',
#  'COA6',
#  'CXCL12',
#  'CYTH3',
#  'DAP',
#  'DEK',
#  'DNAJC15',
#  'DPF3',
#  'FADS3',
#  'FAM118A',
#  'FAM53B',
#  'FBLN7',
#  'FRAS1',
#  'GFOD1',
#  'GNA14',
#  'GRIN3A',
#  'GUCA1B',
#  'HELB',
#  'HIP1',
#  'HNRNPR',
#  'IFIT1',
#  'IFIT5',
#  'IL21R-AS1',
#  'IQGAP2',
#  'ITPK1',
#  'JAM3',
#  'KCNG1',
#  'LAMP5',
#  'LINC00534',
#  'LINC01931',
#  'LINC02248',
#  'LURAP1L',
#  'LYRM7',
#  'MAPK4',
#  'MCM4',
#  'MCOLN3',
#  'MGAT5B',
#  'NETO2',
#  'NPAS3',
#  'NRG1',
#  'NUCKS1',
#  'PDGFC',
#  'PIK3R3',
#  'PJA2',
#  'PLXNA3',
#  'RAB22A',
#  'RBBP7',
#  'RBM20',
#  'RIF1',
#  'RUNX1T1',
#  'SCART1',
#  'SDC2',
#  'SEMA5B',
#  'SEMA6D',
#  'SERTM1',
#  'SESN3',
#  'SGSM2',
#  'SH3GL3',
#  'SLC25A18',
#  'SLC35F3',
#  'SNTG2',
#  'SPNS2',
#  'ST3GAL6',
#  'ST8SIA3',
#  'STK33',
#  'SUSD4',
#  'SYT13',
#  'SYT6',
#  'TAP2',
#  'TERF2IP',
#  'TMCO1',
#  'TMEM220',
#  'VASH1',
#  'YWHAQ',
#  'ZDHHC11B',
#  'ZMIZ1',
#  'ZNF483'}

# %%
celltype_dfs['GN.1'][celltype_dfs['GN.1']['gene_name'] ==  'SEMA5B']
# Out:
#     TFBS_chr  TFBS_start   TFBS_end         TFBS_name  TFBS_score TFBS_strand  \
# 557     chr3   123027791  123027801    KLF11_MA1512.2     7.22719           -
# 545     chr3   123027519  123027529    ZBED4_MA2328.1     9.57853           -
# 556     chr3   123028009  123028019   ZNF148_MA1653.2     7.61743           +
# 558     chr3   123027800  123027810   ZNF148_MA1653.2     8.54208           -
# 559     chr3   123027787  123027795      MAZ_MA1522.2    10.55435           -
# 546     chr3   123027786  123027795    KLF12_MA0742.2     6.70351           +
# 547     chr3   123027791  123027801      SP9_MA1564.2     8.36596           -
# 544     chr3   123027004  123027013    KLF14_MA0740.2     8.07385           +
# 551     chr3   123027784  123027798   ZNF530_MA1981.2     7.56801           +
# 568     chr3   123027792  123027801    KLF10_MA1511.2     8.08997           +
# 569     chr3   123027801  123027810      SP2_MA0516.3     7.25603           +
# 570     chr3   123027791  123027802    KLF16_MA0741.1     7.31960           -
# 571     chr3   123027786  123027796     KLF5_MA0599.1     8.77637           -
# 572     chr3   123027787  123027795     KLF4_MA0039.5     7.61250           -
# 560     chr3   123028000  123028015   ZNF669_MA1985.1     6.44930           +
# 561     chr3   123027792  123027806    PLAG1_MA0163.1     7.40579           +
# 562     chr3   123028008  123028022   ZNF530_MA1981.2     9.86936           -
# 563     chr3   123027801  123027810      SP1_MA0079.5     9.49061           +
# 536     chr3   123027005  123027013    KLF15_MA1513.2     9.40106           -
# 564     chr3   123027004  123027013      SP2_MA0516.3     7.77380           +
# 565     chr3   123027792  123027801      SP1_MA0079.5     8.60471           +
# 566     chr3   123027786  123027795      SP4_MA0685.2     8.81083           +
# 567     chr3   123028645  123028653    TFDP1_MA1122.2     7.35771           +
# 552     chr3   123027801  123027810      SP4_MA0685.2     9.45755           +
# 553     chr3   123027785  123027795   ZNF148_MA1653.2    10.57676           -
# 554     chr3   123027786  123027795      SP2_MA0516.3     7.62240           +
# 555     chr3   123028009  123028019   ZNF281_MA1630.3     7.46775           -
# 537     chr3   123028645  123028653     E2F6_MA0471.3     8.60090           +
# 538     chr3   123027793  123027801     KLF7_MA1959.2     8.77695           +
# 539     chr3   123027789  123027797    CTCFL_MA1102.3     8.48882           +
# 540     chr3   123027521  123027531   ZNF610_MA1713.2    12.17814           -
# 541     chr3   123027800  123027810   ZNF281_MA1630.3    10.03539           +
# 542     chr3   123027787  123027795     KLF1_MA0493.3     8.55607           +
# 543     chr3   123028002  123028013   ZNF682_MA1599.2     8.16176           +
# 550     chr3   123027208  123027222  Tfcp2l1_MA0145.2     8.24056           +
# 549     chr3   123027785  123027796    PATZ1_MA1961.2     9.88518           +
# 548     chr3   123027204  123027212   ZNF692_MA1986.2     9.53724           +
#
#     peak_chr  peak_start   peak_end      peak_id  ... AveExpr_x adj.P.Val_x  \
# 557     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 545     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 556     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 558     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 559     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 546     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 547     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 544     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 551     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 568     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 569     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 570     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 571     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 572     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 560     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 561     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 562     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 563     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 536     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 564     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 565     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 566     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 567     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 552     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 553     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 554     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 555     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 537     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 538     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 539     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 540     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 541     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 542     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 543     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 550     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 549     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
# 548     chr3   123026159  123028776  peak_113568  ...  6.285134    0.033465
#
#      gene_y   logFC_y  AveExpr_y  adj.P.Val_y    gene     logFC   AveExpr  \
# 557  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 545  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 556  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 558  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 559  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 546  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 547  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 544  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 551  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 568  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 569  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 570  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 571  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 572  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 560  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 561  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 562  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 563  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 536  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 564  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 565  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 566  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 567  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 552  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 553  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 554  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 555  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 537  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 538  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 539  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 540  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 541  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 542  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 543  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 550  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 549  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
# 548  SEMA5B -0.236242   6.285134     0.033465  SEMA5B -0.236242  6.285134
#
#     adj.P.Val
# 557  0.033465
# 545  0.033465
# 556  0.033465
# 558  0.033465
# 559  0.033465
# 546  0.033465
# 547  0.033465
# 544  0.033465
# 551  0.033465
# 568  0.033465
# 569  0.033465
# 570  0.033465
# 571  0.033465
# 572  0.033465
# 560  0.033465
# 561  0.033465
# 562  0.033465
# 563  0.033465
# 536  0.033465
# 564  0.033465
# 565  0.033465
# 566  0.033465
# 567  0.033465
# 552  0.033465
# 553  0.033465
# 554  0.033465
# 555  0.033465
# 537  0.033465
# 538  0.033465
# 539  0.033465
# 540  0.033465
# 541  0.033465
# 542  0.033465
# 543  0.033465
# 550  0.033465
# 549  0.033465
# 548  0.033465
#
# [37 rows x 31 columns]

# %%
celltype_dfs['GN.1']= celltype_dfs['GN.1'].sort_values('logFC', ascending=False)
gn1_use = celltype_dfs['GN.1'][['gene', 'TFBS_name', 'logFC', 'AveExpr','GN.1MDD_bound','TFBS_chr', 'TFBS_start', 'TFBS_end']]

# %%
gn1_use['highlight_region'] = gn1_use[['TFBS_chr', 'TFBS_start', 'TFBS_end']].astype(str).agg('-'.join, axis=1)
# Out:
# /tmp/mp4486/ipykernel_332211/881917097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gn1_use['highlight_region'] = gn1_use[['TFBS_chr', 'TFBS_start', 'TFBS_end']].astype(str).agg('-'.join, axis=1)

# %%
gn1_use.sort_values('AveExpr', ascending=False).head(100).sort_values('logFC', ascending=False)
# Out:
#         gene        TFBS_name     logFC   AveExpr  GN.1MDD_bound TFBS_chr  \
# 101     NRG1     SP4_MA0685.2  0.678469  8.423643              1     chr8
# 110     NRG1   KLF10_MA1511.2  0.678469  8.423643              1     chr8
# 117     NRG1  TFAP2B_MA0811.2  0.678469  8.423643              1     chr8
# 112     NRG1   KLF14_MA0740.2  0.678469  8.423643              1     chr8
# 109     NRG1   KLF12_MA0742.2  0.678469  8.423643              1     chr8
# ..       ...              ...       ...       ...            ...      ...
# 897  SLC35F3     SP4_MA0685.2 -0.642352  9.293730              0     chr1
# 886  SLC35F3   TFDP1_MA1122.2 -0.642352  9.293730              0     chr1
# 883  SLC35F3  ZNF148_MA1653.2 -0.642352  9.293730              0     chr1
# 881  SLC35F3     SP2_MA0516.3 -0.642352  9.293730              0     chr1
# 893  SLC35F3    KLF5_MA0599.1 -0.642352  9.293730              0     chr1
#
#      TFBS_start   TFBS_end          highlight_region
# 101    31640308   31640317    chr8-31640308-31640317
# 110    31640308   31640317    chr8-31640308-31640317
# 117    31640024   31640035    chr8-31640024-31640035
# 112    31640308   31640317    chr8-31640308-31640317
# 109    31640308   31640317    chr8-31640308-31640317
# ..          ...        ...                       ...
# 897   233905376  233905385  chr1-233905376-233905385
# 886   233905369  233905377  chr1-233905369-233905377
# 883   233905466  233905476  chr1-233905466-233905476
# 881   233905466  233905475  chr1-233905466-233905475
# 893   233905376  233905386  chr1-233905376-233905386
#
# [100 rows x 9 columns]

# %%
len(list(gn1_use[gn1_use['gene']== 'SEMA5B']['highlight_region']))
# Out:
# 37

# %%
celltype_dfs['GN.1'][celltype_dfs['GN.1']['gene']== 'SUSD4']
# Out:
#     TFBS_chr  TFBS_start   TFBS_end        TFBS_name  TFBS_score TFBS_strand  \
# 522     chr1   223364095  223364105  ZNF148_MA1653.2     8.54208           +
# 528     chr1   223364089  223364098     SP2_MA0516.3     7.71798           -
# 521     chr1   223363237  223363257  ZNF320_MA1976.2     5.81996           -
# 520     chr1   223364932  223364940    KLF4_MA0039.5     8.27062           +
# 523     chr1   223364095  223364105  ZNF281_MA1630.3    10.03539           -
# 517     chr1   223365196  223365210  ZNF530_MA1981.2     8.55087           -
# 518     chr1   223364089  223364098   KLF12_MA0742.2     6.66238           -
# 519     chr1   223364577  223364587  ZNF148_MA1653.2     7.61743           +
# 504     chr1   223364544  223364558  ZNF574_MA1982.2     6.96527           -
# 505     chr1   223365009  223365017  PLAGL2_MA1548.2     7.59842           +
# 502     chr1   223365004  223365012   KLF15_MA1513.2     7.16920           -
# 503     chr1   223364095  223364104     SP1_MA0079.5     9.49061           -
# 516     chr1   223364932  223364940    KLF2_MA1515.2     8.75251           +
# 514     chr1   223363242  223363256  ZNF530_MA1981.2     7.14290           -
# 513     chr1   223364098  223364108   ZBED4_MA2328.1     7.19484           +
# 506     chr1   223363244  223363254  ZBTB24_MA2330.1     7.93586           +
# 515     chr1   223365032  223365042  ZNF610_MA1713.2     7.09763           +
# 511     chr1   223364932  223364941    KLF6_MA1517.2     8.86645           +
# 510     chr1   223363274  223363282    KLF7_MA1959.2     8.77695           -
# 507     chr1   223364095  223364104     SP4_MA0685.2     9.45755           -
# 508     chr1   223365020  223365030     Zfx_MA0146.3     7.98856           +
# 509     chr1   223364577  223364587  ZNF281_MA1630.3     7.46775           -
# 524     chr1   223364932  223364940    KLF1_MA0493.3     8.79673           -
# 525     chr1   223364091  223364102   PATZ1_MA1961.2     7.57080           -
# 526     chr1   223365030  223365038     MAZ_MA1522.2     7.00363           -
# 527     chr1   223363260  223363268    MYF5_MA1641.2     8.38009           +
# 512     chr1   223364636  223364646     Zfx_MA0146.3    10.16143           +
# 529     chr1   223364873  223364879   Foxn1_MA1684.1     7.05757           -
# 530     chr1   223364576  223364590  ZNF530_MA1981.2     9.86936           -
#
#     peak_chr  peak_start   peak_end     peak_id  ... AveExpr_x adj.P.Val_x  \
# 522     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 528     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 521     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 520     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 523     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 517     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 518     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 519     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 504     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 505     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 502     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 503     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 516     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 514     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 513     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 506     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 515     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 511     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 510     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 507     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 508     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 509     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 524     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 525     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 526     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 527     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 512     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 529     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
# 530     chr1   223362972  223365521  peak_13937  ...   8.79127    0.040316
#
#     gene_y   logFC_y  AveExpr_y  adj.P.Val_y   gene     logFC  AveExpr  \
# 522  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 528  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 521  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 520  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 523  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 517  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 518  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 519  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 504  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 505  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 502  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 503  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 516  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 514  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 513  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 506  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 515  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 511  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 510  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 507  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 508  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 509  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 524  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 525  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 526  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 527  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 512  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 529  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
# 530  SUSD4 -0.210015    8.79127     0.040316  SUSD4 -0.210015  8.79127
#
#     adj.P.Val
# 522  0.040316
# 528  0.040316
# 521  0.040316
# 520  0.040316
# 523  0.040316
# 517  0.040316
# 518  0.040316
# 519  0.040316
# 504  0.040316
# 505  0.040316
# 502  0.040316
# 503  0.040316
# 516  0.040316
# 514  0.040316
# 513  0.040316
# 506  0.040316
# 515  0.040316
# 511  0.040316
# 510  0.040316
# 507  0.040316
# 508  0.040316
# 509  0.040316
# 524  0.040316
# 525  0.040316
# 526  0.040316
# 527  0.040316
# 512  0.040316
# 529  0.040316
# 530  0.040316
#
# [29 rows x 31 columns]

# %%
celltype_dfs['GN.1'].to_csv(os.path.join('combined_TF_hits_per_celltype/', f"GN.1_combined_filtered_final.csv"), index=False)
